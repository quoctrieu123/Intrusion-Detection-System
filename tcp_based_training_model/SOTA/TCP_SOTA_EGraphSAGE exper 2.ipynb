# %%
import pandas as pd
train_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_tcp_based\chunk-based-split-1-exper2\train_df_prepared.parquet")
valid_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_tcp_based\chunk-based-split-1-exper2\valid_df_prepared.parquet")
test_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_tcp_based\chunk-based-split-1-exper2\test_df_prepared.parquet")

# %%
train_df["timestamp_num"] = pd.to_datetime(train_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
valid_df["timestamp_num"] = pd.to_datetime(valid_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
test_df["timestamp_num"] = pd.to_datetime(test_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9

# %%
train_df.sort_values(by='timestamp_num', inplace=True)
valid_df.sort_values(by='timestamp_num', inplace=True)
test_df.sort_values(by='timestamp_num', inplace=True)

# %% [markdown]
# ### 1. Chuẩn bị dữ liệu Đồ thị (Graph Data Preparation) cho PyG
# Chuyển đổi DataFrame thành cấu trúc `edge_index` và `edge_attr` của PyTorch Geometric.

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch_geometric.data import Data

print("--- BƯỚC 1: XỬ LÝ IP VÀ TẠO MAPPING ---")
all_ips = pd.concat([
    train_df['src_ip'], train_df['dst_ip'],
    valid_df['src_ip'], valid_df['dst_ip'],
    test_df['src_ip'], test_df['dst_ip']
]).unique()

ip_to_id = {ip: i for i, ip in enumerate(all_ips)}
num_nodes = len(all_ips)
print(f"Tổng số Nodes (IP duy nhất) trong toàn bộ dữ liệu: {num_nodes}")

def prepare_dynamic_graphs(df, ip_dict, window_size_sec=600):
    """Hàm CHUẨN MỰC: Cắt lược DataFrame thành mảng các Đồ thị theo Cửa sổ thời gian (Time-Windows)
       -> Giữ nguyên tính lịch sử thời gian, KO BỊ TEMPORAL LEAKAGE!"""
    min_time = df['timestamp_num'].min()
    
    # Tránh SettingWithCopyWarning
    df = df.copy()
    # Phân lô thời gian (VD: Cứ 600 giây thành 1 cục)
    df['time_window'] = ((df['timestamp_num'] - min_time) // window_size_sec).astype(int)
    
    dynamic_graphs = []
    cols_to_drop = ['flow_id', 'timestamp', 'timestamp_num', 'time_window', 'src_ip', 'dst_ip', 'protocol', 'src_port', 'dst_port', 'label']
    cols_to_drop = [c for c in cols_to_drop if c in df.columns]
    
    # Nhóm theo từng cửa sổ thời gian (Quá khứ -> Hiện tại -> Tương lai)
    for window_id, group in df.groupby('time_window'):
        if len(group) == 0:
            continue
            
        src_nodes = group['src_ip'].map(ip_dict).values
        dst_nodes = group['dst_ip'].map(ip_dict).values
        edge_index = torch.tensor(np.vstack([src_nodes, dst_nodes]), dtype=torch.long)
        
        edge_features = group.drop(columns=cols_to_drop).values
        edge_attr = torch.tensor(edge_features, dtype=torch.float32)
        
        labels = torch.tensor(group['label'].values, dtype=torch.long)
        
        # Bọc thành đối tượng PyG Data của KHUÔN HÌNH THỜI GIAN đó
        snapshot = Data(
            num_nodes=len(ip_dict), 
            edge_index=edge_index, 
            edge_attr=edge_attr, 
            y=labels
        )
        dynamic_graphs.append(snapshot)
        
    return dynamic_graphs

print("\n--- BƯỚC 2: CẮT ĐỒ THỊ THEO THỜI GIAN (TIME-WINDOW GRAPHS) ---")
WINDOW_SIZE = 600 # Nhóm từng khoảng 10 phút (600 giây) thành 1 đồ thị chuẩn
print(f"Đang tiến hành cắt đồ thị với cửa sổ {WINDOW_SIZE} giây / snapshot...")

train_graphs = prepare_dynamic_graphs(train_df, ip_to_id, WINDOW_SIZE)
valid_graphs = prepare_dynamic_graphs(valid_df, ip_to_id, WINDOW_SIZE)
test_graphs = prepare_dynamic_graphs(test_df, ip_to_id, WINDOW_SIZE)

print(f"-> Tập Train được cắt thành {len(train_graphs):,} Snapshots (Snapshot Đồ Thị Thời Gian)")
print(f"-> Tổng lưu lượng Edges trong Train: {sum([g.num_edges for g in train_graphs]):,}")
# Out:
# --- BƯỚC 1: XỬ LÝ IP VÀ TẠO MAPPING ---
# Tổng số Nodes (IP duy nhất) trong toàn bộ dữ liệu: 49
#
# --- BƯỚC 2: CẮT ĐỒ THỊ THEO THỜI GIAN (TIME-WINDOW GRAPHS) ---
# Đang tiến hành cắt đồ thị với cửa sổ 600 giây / snapshot...
# -> Tập Train được cắt thành 25 Snapshots (Snapshot Đồ Thị Thời Gian)
# -> Tổng lưu lượng Edges trong Train: 3,294,945

# %% [markdown]
# ### 2. Kiểm tra Đặc tính đồ thị (Graph Diagnostic Checks)
# Dùng PyTorch Geometric `Data` object để bọc dữ liệu và tiến hành check tính hợp lệ của đồ thị (Label Imbalance, NaNs/Infs, Self-loops...)

# %%
from torch_geometric.data import Data

print("--- BƯỚC 3: KIỂM TRA ĐẶC TÍNH CỦA ĐỒ THỊ THỜI GIAN (DIAGNOSTIC CHECKS) ---")

# Lấy thử Snapshot đầu tiên và Snapshot bất kỳ có nhiều luồng nhất để phân tích
max_edge_graph = max(train_graphs, key=lambda g: g.num_edges)
first_graph = train_graphs[0]

print(f"1. Cấu trúc tổng quát của MỘT SỐ Đồ thị con (Snapshot lớn nhất):")
print(f"   - Số lượng Nút (IP): {max_edge_graph.num_nodes:,} (Khung IP cố định)")
print(f"   - Số lượng Cạnh (Flows): {max_edge_graph.num_edges:,}")
print(f"   - Đồ thị có chứa vòng lặp (Self-loops): {max_edge_graph.has_self_loops()}")
print(f"   - Đồ thị có Nút cô lập (Isolated Nodes)? {max_edge_graph.has_isolated_nodes()}")

print("\n2. Kiểm tra tính hợp lệ của Feature trên Snapshot đầu tiên:")
has_nan = torch.isnan(first_graph.edge_attr).any().item()
has_inf = torch.isinf(first_graph.edge_attr).any().item()
print(f"   - Có chứa giá trị NaN? {'CÓ LỖI' if has_nan else 'Không (An toàn)'}")
print(f"   - Có chứa giá trị Inf? {'CÓ LỖI' if has_inf else 'Không (An toàn)'}")

print("\n3. Kiểm tra tính Đa đồ thị (Multi-graph) trong Snapshot 10 phút nhỏ này:")
unique_edges = torch.unique(max_edge_graph.edge_index, dim=1).shape[1]
duplicate_edges = max_edge_graph.num_edges - unique_edges
print(f"   - Số cạnh trùng lặp trên cùng cặp IP: {duplicate_edges:,} / {max_edge_graph.num_edges:,} flows")
if duplicate_edges > 0:
    print("   -> Snapshot trong 10 phút là Multi-graph, mô phỏng đúng Network Burst (Bùng nổ băng thông)!")
    print("   -> (Giải pháp E-GraphSAGE dùng aggr='max' đã được chuẩn bị để quét các tín hiệu ẩn)")

print("\n4. Kiểm tra phân phối Nhãn (Class Imbalance) trên toàn bộ các Snapshot Train:")
total_label_counts = torch.zeros(13, dtype=torch.int64) 
total_edges = sum([g.num_edges for g in train_graphs])

for g in train_graphs:
    counts = torch.bincount(g.y, minlength=13)
    total_label_counts += counts

for i, count in enumerate(total_label_counts[:13]):
    if count > 0:
        percentage = (count.item() / total_edges) * 100
        print(f"   - Lớp {i}: {count.item():>9,} flows ({percentage:>6.2f}%)")
# Out:
# --- BƯỚC 3: KIỂM TRA ĐẶC TÍNH CỦA ĐỒ THỊ THỜI GIAN (DIAGNOSTIC CHECKS) ---
# 1. Cấu trúc tổng quát của MỘT SỐ Đồ thị con (Snapshot lớn nhất):
#    - Số lượng Nút (IP): 49 (Khung IP cố định)
#    - Số lượng Cạnh (Flows): 613,217
#    - Đồ thị có chứa vòng lặp (Self-loops): False
#    - Đồ thị có Nút cô lập (Isolated Nodes)? True
#
# 2. Kiểm tra tính hợp lệ của Feature trên Snapshot đầu tiên:
#    - Có chứa giá trị NaN? Không (An toàn)
#    - Có chứa giá trị Inf? Không (An toàn)
#
# 3. Kiểm tra tính Đa đồ thị (Multi-graph) trong Snapshot 10 phút nhỏ này:
#    - Số cạnh trùng lặp trên cùng cặp IP: 613,196 / 613,217 flows
#    -> Snapshot trong 10 phút là Multi-graph, mô phỏng đúng Network Burst (Bùng nổ băng thông)!
#    -> (Giải pháp E-GraphSAGE dùng aggr='max' đã được chuẩn bị để quét các tín hiệu ẩn)
#
# 4. Kiểm tra phân phối Nhãn (Class Imbalance) trên toàn bộ các Snapshot Train:
#    - Lớp 0:   246,000 flows (  7.47%)
#    - Lớp 1:   613,217 flows ( 18.61%)
#    - Lớp 2:    92,156 flows (  2.80%)
#    - Lớp 3:   552,845 flows ( 16.78%)
#    - Lớp 4:   275,492 flows (  8.36%)
#    - Lớp 5:   234,000 flows (  7.10%)
#    - Lớp 6:   689,482 flows ( 20.93%)
#    - Lớp 7:    69,051 flows (  2.10%)
#    - Lớp 8:   157,260 flows (  4.77%)
#    - Lớp 9:     1,960 flows (  0.06%)
#    - Lớp 10:     1,358 flows (  0.04%)
#    - Lớp 11:    25,971 flows (  0.79%)
#    - Lớp 12:   336,153 flows ( 10.20%)

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing

# 1. ĐỊNH NGHĨA LỚP MESSAGE PASSING KẾT HỢP CẠNH (EDGE-ENHANCED SAGE)
class EdgeSAGEConv(MessagePassing):
    def __init__(self, in_channels, out_channels, edge_channels, dropout=0.2):
        # TỐI ƯU 1: Đổi từ 'mean' sang 'max' pooling
        # Vì data bị vón cục (nhiều flow cùng 1 class lấn át), 'mean' sẽ cào bằng làm tàng hình class phụ.
        # 'max' pooling giúp GraphSAGE bắt được tín hiệu của các luồng dị biệt (cực kỳ hiệu quả cho Intrusion Detection)
        super().__init__(aggr='max') 
        
        self.msg_mlp = nn.Sequential(
            nn.Linear(in_channels + edge_channels, out_channels),
            nn.LayerNorm(out_channels),
            nn.ReLU(),
            nn.Dropout(dropout) # Thêm nhiễu để bớt học vẹt bối cảnh hàng xóm
        )
        
        self.update_mlp = nn.Sequential(
            nn.Linear(in_channels + out_channels, out_channels),
            nn.LayerNorm(out_channels),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

    def forward(self, x, edge_index, edge_attr):
        return self.propagate(edge_index, x=x, edge_attr=edge_attr)

    def message(self, x_j, edge_attr):
        msg_input = torch.cat([x_j, edge_attr], dim=-1)
        return self.msg_mlp(msg_input)

    def update(self, aggr_out, x):
        update_input = torch.cat([x, aggr_out], dim=-1)
        return self.update_mlp(update_input)

# 2. ĐỊNH NGHĨA MODEL TỔNG THỂ 
class EGraphSAGE(nn.Module):
    def __init__(self, num_nodes, node_emb_dim, edge_in_dim, hidden_dim, num_classes):
        super().__init__()
        self.node_emb = nn.Embedding(num_nodes, node_emb_dim)
        
        self.edge_norm = nn.LayerNorm(edge_in_dim) 
        
        # Thêm dropout nhẹ vào Convolution
        self.conv1 = EdgeSAGEConv(node_emb_dim, hidden_dim, edge_in_dim, dropout=0.1)
        self.conv2 = EdgeSAGEConv(hidden_dim, hidden_dim, edge_in_dim, dropout=0.1)
        
        classifier_dim = hidden_dim * 2 + edge_in_dim
        self.classifier = nn.Sequential(
            nn.Linear(classifier_dim, hidden_dim * 2),
            nn.LayerNorm(hidden_dim * 2),
            nn.ReLU(),
            nn.Dropout(0.4), # Tăng Dropout tầng cuối để chống Overfitting
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(hidden_dim, num_classes)
        )

    def encode_context(self, edge_index, edge_attr):
        clean_attr = torch.nan_to_num(edge_attr, nan=0.0, posinf=0.0, neginf=0.0)
        clean_attr = self.edge_norm(clean_attr)
        
        x = self.node_emb.weight
        x = F.relu(self.conv1(x, edge_index, clean_attr))
        x = self.conv2(x, edge_index, clean_attr)
        return x, clean_attr

    def predict_edges(self, x_context, clean_attr, edge_index, query_idx):
        src_nodes = edge_index[0, query_idx]
        dst_nodes = edge_index[1, query_idx]
        batch_attr = clean_attr[query_idx]
        
        edge_repr = torch.cat([x_context[src_nodes], x_context[dst_nodes], batch_attr], dim=-1)
        return self.classifier(edge_repr)

print("Đã xây dựng xong Mô Hình SAGE (Tối ưu hóa Aggregation & Dropout)!")
# Out:
# Đã xây dựng xong Mô Hình SAGE (Tối ưu hóa Aggregation & Dropout)!

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 13  # Cập nhật thành 13 lớp cho dữ liệu TCP-BASED

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 50.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.22481126 0.09018598 0.6001082  0.10003449 0.20074475 0.23634005
#  0.08021031 0.80090904 0.35166967 4.010516   4.010516   2.1294355
#  0.16451904]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 20        
EVAL_FREQ = 2       # [TĂNG TỐC] Chỉ đánh giá (Validation) sau mỗi 2 epoch

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

# [TĂNG TỐC] Dùng AMP (Automatic Mixed Precision) để giảm một nửa thời gian train trên GPU
scaler = torch.amp.GradScaler('cuda')

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT VỚI FP16 AMP (SIÊU NHANH)
        with torch.amp.autocast('cuda'):
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            with torch.amp.autocast('cuda'):
                preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
                # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
                loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            
            # Quản lý scale loss cho FP16
            scaler.scale(loss).backward() 
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        # Step optimizer thông qua scaler
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()
            
    avg_train_loss = total_train_loss / total_train_edges
    current_lr = optimizer.param_groups[0]['lr']
    
    # [TĂNG TỐC] CHỈ CHẠY VALIDATION Ở CÁC EPOCH CHẴN
    if (epoch + 1) % EVAL_FREQ == 0 or epoch == 0:
        val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
        scheduler.step(val_f1)
        
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
        
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
        else:
            patience_counter += EVAL_FREQ
            if patience_counter >= patience:
                print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
                break
    else:
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | --- Skipped Validation ---")

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 4.7211 | Val Loss: 3.8835 | Val F1: 0.0203
#    -> Epoch 1: Kỷ lục F1 mới (0.0203)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 3.8329 | Val Loss: 3.1770 | Val F1: 0.1835
#    -> Epoch 2: Kỷ lục F1 mới (0.1835)! Đã lưu trọng số.
# Epoch  3/100 | LR: 0.001000 | Train Loss: 3.4232 | --- Skipped Validation ---
# Epoch  4/100 | LR: 0.001000 | Train Loss: 3.2305 | Val Loss: 2.8874 | Val F1: 0.2212
#    -> Epoch 4: Kỷ lục F1 mới (0.2212)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 3.2697 | --- Skipped Validation ---
# Epoch  6/100 | LR: 0.001000 | Train Loss: 3.0845 | Val Loss: 2.6156 | Val F1: 0.3116
#    -> Epoch 6: Kỷ lục F1 mới (0.3116)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.001000 | Train Loss: 3.0756 | --- Skipped Validation ---
# Epoch  8/100 | LR: 0.001000 | Train Loss: 2.8201 | Val Loss: 2.5895 | Val F1: 0.3653
#    -> Epoch 8: Kỷ lục F1 mới (0.3653)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.001000 | Train Loss: 2.9866 | --- Skipped Validation ---
# Epoch 10/100 | LR: 0.001000 | Train Loss: 2.6709 | Val Loss: 2.4448 | Val F1: 0.3590
# Epoch 11/100 | LR: 0.001000 | Train Loss: 2.6902 | --- Skipped Validation ---
# Epoch 12/100 | LR: 0.001000 | Train Loss: 2.5193 | Val Loss: 2.4185 | Val F1: 0.3160
# Epoch 13/100 | LR: 0.001000 | Train Loss: 2.3371 | --- Skipped Validation ---
# Epoch 14/100 | LR: 0.001000 | Train Loss: 2.5770 | Val Loss: 2.1820 | Val F1: 0.5040
#    -> Epoch 14: Kỷ lục F1 mới (0.5040)! Đã lưu trọng số.
# Epoch 15/100 | LR: 0.001000 | Train Loss: 2.3242 | --- Skipped Validation ---
# Epoch 16/100 | LR: 0.001000 | Train Loss: 2.5353 | Val Loss: 2.3886 | Val F1: 0.4276
# Epoch 17/100 | LR: 0.001000 | Train Loss: 2.2667 | --- Skipped Validation ---
# Epoch 18/100 | LR: 0.001000 | Train Loss: 2.0271 | Val Loss: 1.8283 | Val F1: 0.7152
#    -> Epoch 18: Kỷ lục F1 mới (0.7152)! Đã lưu trọng số.
# Epoch 19/100 | LR: 0.001000 | Train Loss: 2.0840 | --- Skipped Validation ---
# Epoch 20/100 | LR: 0.001000 | Train Loss: 1.9868 | Val Loss: 1.8620 | Val F1: 0.7013
# Epoch 21/100 | LR: 0.001000 | Train Loss: 1.8986 | --- Skipped Validation ---
# Epoch 22/100 | LR: 0.001000 | Train Loss: 2.1159 | Val Loss: 1.8602 | Val F1: 0.7618
#    -> Epoch 22: Kỷ lục F1 mới (0.7618)! Đã lưu trọng số.
# Epoch 23/100 | LR: 0.001000 | Train Loss: 1.9114 | --- Skipped Validation ---
# Epoch 24/100 | LR: 0.001000 | Train Loss: 1.7823 | Val Loss: 1.8507 | Val F1: 0.7757
#    -> Epoch 24: Kỷ lục F1 mới (0.7757)! Đã lưu trọng số.
# Epoch 25/100 | LR: 0.001000 | Train Loss: 1.7610 | --- Skipped Validation ---
# Epoch 26/100 | LR: 0.001000 | Train Loss: 1.7916 | Val Loss: 2.1490 | Val F1: 0.7755
# Epoch 27/100 | LR: 0.001000 | Train Loss: 1.6842 | --- Skipped Validation ---
# Epoch 28/100 | LR: 0.001000 | Train Loss: 1.7708 | Val Loss: 2.5052 | Val F1: 0.7711
# Epoch 29/100 | LR: 0.001000 | Train Loss: 1.6147 | --- Skipped Validation ---
# Epoch 30/100 | LR: 0.001000 | Train Loss: 1.6671 | Val Loss: 2.4479 | Val F1: 0.7261
# Epoch 31/100 | LR: 0.000500 | Train Loss: 1.6140 | --- Skipped Validation ---
# Epoch 32/100 | LR: 0.000500 | Train Loss: 1.5787 | Val Loss: 2.4676 | Val F1: 0.7732
# Epoch 33/100 | LR: 0.000500 | Train Loss: 1.5712 | --- Skipped Validation ---
# Epoch 34/100 | LR: 0.000500 | Train Loss: 1.5622 | Val Loss: 2.5021 | Val F1: 0.7715
# Epoch 35/100 | LR: 0.000500 | Train Loss: 1.5625 | --- Skipped Validation ---
# Epoch 36/100 | LR: 0.000500 | Train Loss: 1.5606 | Val Loss: 2.5517 | Val F1: 0.7807
#    -> Epoch 36: Kỷ lục F1 mới (0.7807)! Đã lưu trọng số.
# Epoch 37/100 | LR: 0.000500 | Train Loss: 1.5643 | --- Skipped Validation ---
# Epoch 38/100 | LR: 0.000500 | Train Loss: 1.5550 | Val Loss: 2.5210 | Val F1: 0.7707
# Epoch 39/100 | LR: 0.000500 | Train Loss: 1.5567 | --- Skipped Validation ---
# Epoch 40/100 | LR: 0.000500 | Train Loss: 1.5542 | Val Loss: 2.5384 | Val F1: 0.7771
# Epoch 41/100 | LR: 0.000500 | Train Loss: 1.5604 | --- Skipped Validation ---
# Epoch 42/100 | LR: 0.000500 | Train Loss: 1.5516 | Val Loss: 2.4990 | Val F1: 0.8177
#    -> Epoch 42: Kỷ lục F1 mới (0.8177)! Đã lưu trọng số.
# Epoch 43/100 | LR: 0.000500 | Train Loss: 1.5512 | --- Skipped Validation ---
# Epoch 44/100 | LR: 0.000500 | Train Loss: 1.5529 | Val Loss: 2.5348 | Val F1: 0.7598
# Epoch 45/100 | LR: 0.000500 | Train Loss: 1.5547 | --- Skipped Validation ---
# Epoch 46/100 | LR: 0.000500 | Train Loss: 1.5557 | Val Loss: 2.5549 | Val F1: 0.7853
# Epoch 47/100 | LR: 0.000500 | Train Loss: 1.5513 | --- Skipped Validation ---
# Epoch 48/100 | LR: 0.000500 | Train Loss: 1.5539 | Val Loss: 2.6165 | Val F1: 0.7785
# Epoch 49/100 | LR: 0.000250 | Train Loss: 1.5477 | --- Skipped Validation ---
# Epoch 50/100 | LR: 0.000250 | Train Loss: 1.5443 | Val Loss: 2.5843 | Val F1: 0.7820
# Epoch 51/100 | LR: 0.000250 | Train Loss: 1.5437 | --- Skipped Validation ---
# Epoch 52/100 | LR: 0.000250 | Train Loss: 1.5436 | Val Loss: 2.5883 | Val F1: 0.7807
# Epoch 53/100 | LR: 0.000250 | Train Loss: 1.5428 | --- Skipped Validation ---
# Epoch 54/100 | LR: 0.000250 | Train Loss: 1.5426 | Val Loss: 2.5999 | Val F1: 0.7796
# Epoch 55/100 | LR: 0.000125 | Train Loss: 1.5422 | --- Skipped Validation ---
# Epoch 56/100 | LR: 0.000125 | Train Loss: 1.5421 | Val Loss: 2.5944 | Val F1: 0.7795
# Epoch 57/100 | LR: 0.000125 | Train Loss: 1.5418 | --- Skipped Validation ---
# Epoch 58/100 | LR: 0.000125 | Train Loss: 1.5418 | Val Loss: 2.5923 | Val F1: 0.7801
# Epoch 59/100 | LR: 0.000125 | Train Loss: 1.5414 | --- Skipped Validation ---
# Epoch 60/100 | LR: 0.000125 | Train Loss: 1.5416 | Val Loss: 2.5945 | Val F1: 0.7796
# Epoch 61/100 | LR: 0.000063 | Train Loss: 1.5412 | --- Skipped Validation ---
# Epoch 62/100 | LR: 0.000063 | Train Loss: 1.5411 | Val Loss: 2.5950 | Val F1: 0.7794
#
# => EARLY STOPPING kích hoạt ở Epoch 62 (Ngừng cải thiện sau 20 epochs).
#
# Quá trình Training hoàn tất trong 3509.16 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 2.4905 | Test Macro-F1: 0.8101
#
#               precision    recall  f1-score   support
#
#            0     0.2873    1.0000    0.4464    246000
#            1     0.0000    0.0000    0.0000    613218
#            2     1.0000    0.9998    0.9999     92157
#            3     1.0000    0.9931    0.9965    552847
#            4     0.9999    0.9957    0.9978    275494
#            5     1.0000    0.9970    0.9985    234000
#            6     1.0000    1.0000    1.0000    689483
#            7     0.9997    0.9923    0.9960     69052
#            8     0.9700    1.0000    0.9848    157261
#            9     0.5831    0.2987    0.3950      1962
#           10     0.6851    1.0000    0.8132      1360
#           11     0.8360    0.9840    0.9040     25973
#           12     0.9996    1.0000    0.9998    336156
#
#     accuracy                         0.8115   3294963
#    macro avg     0.7970    0.8662    0.8101   3294963
# weighted avg     0.7575    0.8115    0.7697   3294963

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 13  # Cập nhật thành 13 lớp cho dữ liệu TCP-BASED

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 50.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.22481126 0.09018598 0.6001082  0.10003449 0.20074475 0.23634005
#  0.08021031 0.80090904 0.35166967 4.010516   4.010516   2.1294355
#  0.16451904]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 20        
EVAL_FREQ = 2       # [TĂNG TỐC] Chỉ đánh giá (Validation) sau mỗi 2 epoch

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

# [TĂNG TỐC] Dùng AMP (Automatic Mixed Precision) để giảm một nửa thời gian train trên GPU
scaler = torch.amp.GradScaler('cuda')

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT VỚI FP16 AMP (SIÊU NHANH)
        with torch.amp.autocast('cuda'):
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            with torch.amp.autocast('cuda'):
                preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
                # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
                loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            
            # Quản lý scale loss cho FP16
            scaler.scale(loss).backward() 
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        # Step optimizer thông qua scaler
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()
            
    avg_train_loss = total_train_loss / total_train_edges
    current_lr = optimizer.param_groups[0]['lr']
    
    # [TĂNG TỐC] CHỈ CHẠY VALIDATION Ở CÁC EPOCH CHẴN
    if (epoch + 1) % EVAL_FREQ == 0 or epoch == 0:
        val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
        scheduler.step(val_f1)
        
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
        
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
        else:
            patience_counter += EVAL_FREQ
            if patience_counter >= patience:
                print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
                break
    else:
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | --- Skipped Validation ---")

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 4.4699 | Val Loss: 4.3395 | Val F1: 0.0142
#    -> Epoch 1: Kỷ lục F1 mới (0.0142)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 4.2188 | Val Loss: 3.4055 | Val F1: 0.0843
#    -> Epoch 2: Kỷ lục F1 mới (0.0843)! Đã lưu trọng số.
# Epoch  3/100 | LR: 0.001000 | Train Loss: 3.4921 | --- Skipped Validation ---
# Epoch  4/100 | LR: 0.001000 | Train Loss: 3.3991 | Val Loss: 3.0348 | Val F1: 0.2468
#    -> Epoch 4: Kỷ lục F1 mới (0.2468)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 3.1996 | --- Skipped Validation ---
# Epoch  6/100 | LR: 0.001000 | Train Loss: 2.9912 | Val Loss: 2.6869 | Val F1: 0.2970
#    -> Epoch 6: Kỷ lục F1 mới (0.2970)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.001000 | Train Loss: 2.8433 | --- Skipped Validation ---
# Epoch  8/100 | LR: 0.001000 | Train Loss: 2.7405 | Val Loss: 2.4436 | Val F1: 0.4180
#    -> Epoch 8: Kỷ lục F1 mới (0.4180)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.001000 | Train Loss: 2.5579 | --- Skipped Validation ---
# Epoch 10/100 | LR: 0.001000 | Train Loss: 2.5102 | Val Loss: 2.2667 | Val F1: 0.4191
#    -> Epoch 10: Kỷ lục F1 mới (0.4191)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.001000 | Train Loss: 2.5772 | --- Skipped Validation ---
# Epoch 12/100 | LR: 0.001000 | Train Loss: 2.2878 | Val Loss: 2.5076 | Val F1: 0.4440
#    -> Epoch 12: Kỷ lục F1 mới (0.4440)! Đã lưu trọng số.
# Epoch 13/100 | LR: 0.001000 | Train Loss: 2.8862 | --- Skipped Validation ---
# Epoch 14/100 | LR: 0.001000 | Train Loss: 2.4503 | Val Loss: 2.1279 | Val F1: 0.4991
#    -> Epoch 14: Kỷ lục F1 mới (0.4991)! Đã lưu trọng số.
# Epoch 15/100 | LR: 0.001000 | Train Loss: 2.4288 | --- Skipped Validation ---
# Epoch 16/100 | LR: 0.001000 | Train Loss: 2.1640 | Val Loss: 1.9318 | Val F1: 0.6640
#    -> Epoch 16: Kỷ lục F1 mới (0.6640)! Đã lưu trọng số.
# Epoch 17/100 | LR: 0.001000 | Train Loss: 2.2777 | --- Skipped Validation ---
# Epoch 18/100 | LR: 0.001000 | Train Loss: 2.0751 | Val Loss: 1.8384 | Val F1: 0.6937
#    -> Epoch 18: Kỷ lục F1 mới (0.6937)! Đã lưu trọng số.
# Epoch 19/100 | LR: 0.001000 | Train Loss: 1.9019 | --- Skipped Validation ---
# Epoch 20/100 | LR: 0.001000 | Train Loss: 1.8163 | Val Loss: 1.8129 | Val F1: 0.6949
#    -> Epoch 20: Kỷ lục F1 mới (0.6949)! Đã lưu trọng số.
# Epoch 21/100 | LR: 0.001000 | Train Loss: 1.7559 | --- Skipped Validation ---
# Epoch 22/100 | LR: 0.001000 | Train Loss: 1.7455 | Val Loss: 2.0061 | Val F1: 0.6686
# Epoch 23/100 | LR: 0.001000 | Train Loss: 1.6877 | --- Skipped Validation ---
# Epoch 24/100 | LR: 0.001000 | Train Loss: 1.7659 | Val Loss: 2.4296 | Val F1: 0.7294
#    -> Epoch 24: Kỷ lục F1 mới (0.7294)! Đã lưu trọng số.
# Epoch 25/100 | LR: 0.001000 | Train Loss: 1.6710 | --- Skipped Validation ---
# Epoch 26/100 | LR: 0.001000 | Train Loss: 1.7030 | Val Loss: 2.1185 | Val F1: 0.7177
# Epoch 27/100 | LR: 0.001000 | Train Loss: 1.6880 | --- Skipped Validation ---
# Epoch 28/100 | LR: 0.001000 | Train Loss: 1.7343 | Val Loss: 2.1791 | Val F1: 0.7223
# Epoch 29/100 | LR: 0.001000 | Train Loss: 1.6210 | --- Skipped Validation ---
# Epoch 30/100 | LR: 0.001000 | Train Loss: 1.7083 | Val Loss: 2.4276 | Val F1: 0.8305
#    -> Epoch 30: Kỷ lục F1 mới (0.8305)! Đã lưu trọng số.
# Epoch 31/100 | LR: 0.001000 | Train Loss: 1.6152 | --- Skipped Validation ---
# Epoch 32/100 | LR: 0.001000 | Train Loss: 1.6036 | Val Loss: 2.4853 | Val F1: 0.8220
# Epoch 33/100 | LR: 0.001000 | Train Loss: 1.6223 | --- Skipped Validation ---
# Epoch 34/100 | LR: 0.001000 | Train Loss: 1.5915 | Val Loss: 2.6637 | Val F1: 0.6685
# Epoch 35/100 | LR: 0.001000 | Train Loss: 1.5765 | --- Skipped Validation ---
# Epoch 36/100 | LR: 0.001000 | Train Loss: 1.5838 | Val Loss: 2.6307 | Val F1: 0.7954
# Epoch 37/100 | LR: 0.000500 | Train Loss: 1.5788 | --- Skipped Validation ---
# Epoch 38/100 | LR: 0.000500 | Train Loss: 1.5604 | Val Loss: 2.4998 | Val F1: 0.7926
# Epoch 39/100 | LR: 0.000500 | Train Loss: 1.5580 | --- Skipped Validation ---
# Epoch 40/100 | LR: 0.000500 | Train Loss: 1.5523 | Val Loss: 2.5310 | Val F1: 0.7873
# Epoch 41/100 | LR: 0.000500 | Train Loss: 1.5500 | --- Skipped Validation ---
# Epoch 42/100 | LR: 0.000500 | Train Loss: 1.5507 | Val Loss: 2.5378 | Val F1: 0.7805
# Epoch 43/100 | LR: 0.000250 | Train Loss: 1.5482 | --- Skipped Validation ---
# Epoch 44/100 | LR: 0.000250 | Train Loss: 1.5476 | Val Loss: 2.5308 | Val F1: 0.7828
# Epoch 45/100 | LR: 0.000250 | Train Loss: 1.5472 | --- Skipped Validation ---
# Epoch 46/100 | LR: 0.000250 | Train Loss: 1.5467 | Val Loss: 2.5407 | Val F1: 0.7812
# Epoch 47/100 | LR: 0.000250 | Train Loss: 1.5462 | --- Skipped Validation ---
# Epoch 48/100 | LR: 0.000250 | Train Loss: 1.5455 | Val Loss: 2.5537 | Val F1: 0.7791
# Epoch 49/100 | LR: 0.000125 | Train Loss: 1.5449 | --- Skipped Validation ---
# Epoch 50/100 | LR: 0.000125 | Train Loss: 1.5447 | Val Loss: 2.5530 | Val F1: 0.7788
#
# => EARLY STOPPING kích hoạt ở Epoch 50 (Ngừng cải thiện sau 20 epochs).
#
# Quá trình Training hoàn tất trong 3664.12 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 2.4477 | Test Macro-F1: 0.7163
#
#               precision    recall  f1-score   support
#
#            0     0.2879    0.9986    0.4469    246000
#            1     0.0000    0.0000    0.0000    613218
#            2     0.7924    0.9999    0.8842     92157
#            3     1.0000    0.9981    0.9990    552847
#            4     1.0000    0.8886    0.9410    275494
#            5     1.0000    0.9962    0.9981    234000
#            6     1.0000    1.0000    1.0000    689483
#            7     0.9991    0.8756    0.9333     69052
#            8     0.7718    1.0000    0.8712    157261
#            9     0.3882    0.3700    0.3789      1962
#           10     0.6676    1.0000    0.8007      1360
#           11     0.7505    0.0310    0.0596     25973
#           12     0.9978    1.0000    0.9989    336156
#
#     accuracy                         0.7933   3294963
#    macro avg     0.7427    0.7814    0.7163   3294963
# weighted avg     0.7413    0.7933    0.7486   3294963

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 13  # Cập nhật thành 13 lớp cho dữ liệu TCP-BASED

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 50.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.22481126 0.09018598 0.6001082  0.10003449 0.20074475 0.23634005
#  0.08021031 0.80090904 0.35166967 4.010516   4.010516   2.1294355
#  0.16451904]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 20        
EVAL_FREQ = 2       # [TĂNG TỐC] Chỉ đánh giá (Validation) sau mỗi 2 epoch

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

# [TĂNG TỐC] Dùng AMP (Automatic Mixed Precision) để giảm một nửa thời gian train trên GPU
scaler = torch.amp.GradScaler('cuda')

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT VỚI FP16 AMP (SIÊU NHANH)
        with torch.amp.autocast('cuda'):
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            with torch.amp.autocast('cuda'):
                preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
                # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
                loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            
            # Quản lý scale loss cho FP16
            scaler.scale(loss).backward() 
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        # Step optimizer thông qua scaler
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()
            
    avg_train_loss = total_train_loss / total_train_edges
    current_lr = optimizer.param_groups[0]['lr']
    
    # [TĂNG TỐC] CHỈ CHẠY VALIDATION Ở CÁC EPOCH CHẴN
    if (epoch + 1) % EVAL_FREQ == 0 or epoch == 0:
        val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
        scheduler.step(val_f1)
        
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
        
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
        else:
            patience_counter += EVAL_FREQ
            if patience_counter >= patience:
                print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
                break
    else:
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | --- Skipped Validation ---")

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred = evaluate_graphs(model, test_graphs, criterion, device)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}\n")
print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 4.9369 | Val Loss: 4.9773 | Val F1: 0.0142
#    -> Epoch 1: Kỷ lục F1 mới (0.0142)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 4.4952 | Val Loss: 3.4417 | Val F1: 0.0989
#    -> Epoch 2: Kỷ lục F1 mới (0.0989)! Đã lưu trọng số.
# Epoch  3/100 | LR: 0.001000 | Train Loss: 3.5752 | --- Skipped Validation ---
# Epoch  4/100 | LR: 0.001000 | Train Loss: 3.2788 | Val Loss: 2.8849 | Val F1: 0.2063
#    -> Epoch 4: Kỷ lục F1 mới (0.2063)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 3.0718 | --- Skipped Validation ---
# Epoch  6/100 | LR: 0.001000 | Train Loss: 3.2725 | Val Loss: 2.6270 | Val F1: 0.2725
#    -> Epoch 6: Kỷ lục F1 mới (0.2725)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.001000 | Train Loss: 2.8156 | --- Skipped Validation ---
# Epoch  8/100 | LR: 0.001000 | Train Loss: 2.6995 | Val Loss: 2.3315 | Val F1: 0.4168
#    -> Epoch 8: Kỷ lục F1 mới (0.4168)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.001000 | Train Loss: 2.7506 | --- Skipped Validation ---
# Epoch 10/100 | LR: 0.001000 | Train Loss: 2.5154 | Val Loss: 2.1850 | Val F1: 0.4638
#    -> Epoch 10: Kỷ lục F1 mới (0.4638)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.001000 | Train Loss: 2.4219 | --- Skipped Validation ---
# Epoch 12/100 | LR: 0.001000 | Train Loss: 2.5594 | Val Loss: 2.0297 | Val F1: 0.6003
#    -> Epoch 12: Kỷ lục F1 mới (0.6003)! Đã lưu trọng số.
# Epoch 13/100 | LR: 0.001000 | Train Loss: 2.3992 | --- Skipped Validation ---
# Epoch 14/100 | LR: 0.001000 | Train Loss: 2.2059 | Val Loss: 1.9799 | Val F1: 0.5954
# Epoch 15/100 | LR: 0.001000 | Train Loss: 2.4749 | --- Skipped Validation ---
# Epoch 16/100 | LR: 0.001000 | Train Loss: 2.0008 | Val Loss: 1.9482 | Val F1: 0.5735
# Epoch 17/100 | LR: 0.001000 | Train Loss: 2.0174 | --- Skipped Validation ---
# Epoch 18/100 | LR: 0.001000 | Train Loss: 2.1701 | Val Loss: 1.9919 | Val F1: 0.5738
# Epoch 19/100 | LR: 0.000500 | Train Loss: 1.8275 | --- Skipped Validation ---
# Epoch 20/100 | LR: 0.000500 | Train Loss: 1.7212 | Val Loss: 2.0812 | Val F1: 0.6703
#    -> Epoch 20: Kỷ lục F1 mới (0.6703)! Đã lưu trọng số.
# Epoch 21/100 | LR: 0.000500 | Train Loss: 1.6713 | --- Skipped Validation ---
# Epoch 22/100 | LR: 0.000500 | Train Loss: 1.6608 | Val Loss: 2.0784 | Val F1: 0.6565
# Epoch 23/100 | LR: 0.000500 | Train Loss: 1.6660 | --- Skipped Validation ---
# Epoch 24/100 | LR: 0.000500 | Train Loss: 1.6194 | Val Loss: 2.3863 | Val F1: 0.7380
#    -> Epoch 24: Kỷ lục F1 mới (0.7380)! Đã lưu trọng số.
# Epoch 25/100 | LR: 0.000500 | Train Loss: 1.6174 | --- Skipped Validation ---
# Epoch 26/100 | LR: 0.000500 | Train Loss: 1.6094 | Val Loss: 2.4600 | Val F1: 0.7703
#    -> Epoch 26: Kỷ lục F1 mới (0.7703)! Đã lưu trọng số.
# Epoch 27/100 | LR: 0.000500 | Train Loss: 1.5894 | --- Skipped Validation ---
# Epoch 28/100 | LR: 0.000500 | Train Loss: 1.5894 | Val Loss: 2.3471 | Val F1: 0.7573
# Epoch 29/100 | LR: 0.000500 | Train Loss: 1.5900 | --- Skipped Validation ---
# Epoch 30/100 | LR: 0.000500 | Train Loss: 1.5772 | Val Loss: 2.4730 | Val F1: 0.7528
# Epoch 31/100 | LR: 0.000500 | Train Loss: 1.5908 | --- Skipped Validation ---
# Epoch 32/100 | LR: 0.000500 | Train Loss: 1.5710 | Val Loss: 2.5387 | Val F1: 0.7838
#    -> Epoch 32: Kỷ lục F1 mới (0.7838)! Đã lưu trọng số.
# Epoch 33/100 | LR: 0.000500 | Train Loss: 1.5790 | --- Skipped Validation ---
# Epoch 34/100 | LR: 0.000500 | Train Loss: 1.5662 | Val Loss: 2.4921 | Val F1: 0.7615
# Epoch 35/100 | LR: 0.000500 | Train Loss: 1.5601 | --- Skipped Validation ---
# Epoch 36/100 | LR: 0.000500 | Train Loss: 1.5684 | Val Loss: 2.5514 | Val F1: 0.7599
# Epoch 37/100 | LR: 0.000500 | Train Loss: 1.5620 | --- Skipped Validation ---
# Epoch 38/100 | LR: 0.000500 | Train Loss: 1.5650 | Val Loss: 2.4892 | Val F1: 0.7562
# Epoch 39/100 | LR: 0.000250 | Train Loss: 1.5539 | --- Skipped Validation ---
# Epoch 40/100 | LR: 0.000250 | Train Loss: 1.5500 | Val Loss: 2.5617 | Val F1: 0.7619
# Epoch 41/100 | LR: 0.000250 | Train Loss: 1.5497 | --- Skipped Validation ---
# Epoch 42/100 | LR: 0.000250 | Train Loss: 1.5482 | Val Loss: 2.5619 | Val F1: 0.7652
# Epoch 43/100 | LR: 0.000250 | Train Loss: 1.5476 | --- Skipped Validation ---
# Epoch 44/100 | LR: 0.000250 | Train Loss: 1.5467 | Val Loss: 2.5762 | Val F1: 0.7586
# Epoch 45/100 | LR: 0.000125 | Train Loss: 1.5468 | --- Skipped Validation ---
# Epoch 46/100 | LR: 0.000125 | Train Loss: 1.5463 | Val Loss: 2.5668 | Val F1: 0.7688
# Epoch 47/100 | LR: 0.000125 | Train Loss: 1.5451 | --- Skipped Validation ---
# Epoch 48/100 | LR: 0.000125 | Train Loss: 1.5454 | Val Loss: 2.5809 | Val F1: 0.7641
# Epoch 49/100 | LR: 0.000125 | Train Loss: 1.5447 | --- Skipped Validation ---
# Epoch 50/100 | LR: 0.000125 | Train Loss: 1.5451 | Val Loss: 2.5881 | Val F1: 0.7653
# Epoch 51/100 | LR: 0.000063 | Train Loss: 1.5445 | --- Skipped Validation ---
# Epoch 52/100 | LR: 0.000063 | Train Loss: 1.5451 | Val Loss: 2.5778 | Val F1: 0.7662
#
# => EARLY STOPPING kích hoạt ở Epoch 52 (Ngừng cải thiện sau 20 epochs).
#
# Quá trình Training hoàn tất trong 3767.26 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 2.5568 | Test Macro-F1: 0.7303
#
#               precision    recall  f1-score   support
#
#            0     0.2881    0.9990    0.4472    246000
#            1     0.0000    0.0000    0.0000    613218
#            2     0.9594    0.9999    0.9792     92157
#            3     1.0000    0.9932    0.9966    552847
#            4     1.0000    0.8227    0.9027    275494
#            5     1.0000    0.9965    0.9982    234000
#            6     1.0000    1.0000    1.0000    689483
#            7     0.8292    0.9986    0.9061     69052
#            8     0.7866    0.9995    0.8804    157261
#            9     0.0380    0.0387    0.0384      1962
#           10     0.3727    1.0000    0.5430      1360
#           11     0.8609    0.7507    0.8020     25973
#           12     0.9997    1.0000    0.9999    336156
#
#     accuracy                         0.7950   3294963
#    macro avg     0.7027    0.8153    0.7303   3294963
# weighted avg     0.7439    0.7950    0.7532   3294963
