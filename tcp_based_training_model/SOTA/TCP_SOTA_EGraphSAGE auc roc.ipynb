# %%
import pandas as pd
train_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_tcp_based\chunk-based-split-1-exper2\train_df_prepared.parquet")
valid_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_tcp_based\chunk-based-split-1-exper2\valid_df_prepared.parquet")
test_df = pd.read_parquet(r"C:\Users\Admin\Downloads\IoT Dataset\final_data_tcp_based\chunk-based-split-1-exper2\test_df_prepared.parquet")

# %%
train_df["timestamp_num"] = pd.to_datetime(train_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
valid_df["timestamp_num"] = pd.to_datetime(valid_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9
test_df["timestamp_num"] = pd.to_datetime(test_df['timestamp'], format='mixed', utc=True).astype('int64') / 1e9

# %%
train_df.sort_values(by='timestamp_num', inplace=True)
valid_df.sort_values(by='timestamp_num', inplace=True)
test_df.sort_values(by='timestamp_num', inplace=True)

# %% [markdown]
# ### 1. Chuẩn bị dữ liệu Đồ thị (Graph Data Preparation) cho PyG
# Chuyển đổi DataFrame thành cấu trúc `edge_index` và `edge_attr` của PyTorch Geometric.

# %%
import torch
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from torch_geometric.data import Data

print("--- BƯỚC 1: XỬ LÝ IP VÀ TẠO MAPPING ---")
all_ips = pd.concat([
    train_df['src_ip'], train_df['dst_ip'],
    valid_df['src_ip'], valid_df['dst_ip'],
    test_df['src_ip'], test_df['dst_ip']
]).unique()

ip_to_id = {ip: i for i, ip in enumerate(all_ips)}
num_nodes = len(all_ips)
print(f"Tổng số Nodes (IP duy nhất) trong toàn bộ dữ liệu: {num_nodes}")

def prepare_dynamic_graphs(df, ip_dict, window_size_sec=600):
    """Hàm CHUẨN MỰC: Cắt lược DataFrame thành mảng các Đồ thị theo Cửa sổ thời gian (Time-Windows)
       -> Giữ nguyên tính lịch sử thời gian, KO BỊ TEMPORAL LEAKAGE!"""
    min_time = df['timestamp_num'].min()
    
    # Tránh SettingWithCopyWarning
    df = df.copy()
    # Phân lô thời gian (VD: Cứ 600 giây thành 1 cục)
    df['time_window'] = ((df['timestamp_num'] - min_time) // window_size_sec).astype(int)
    
    dynamic_graphs = []
    cols_to_drop = ['flow_id', 'timestamp', 'timestamp_num', 'time_window', 'src_ip', 'dst_ip', 'protocol', 'src_port', 'dst_port', 'label']
    cols_to_drop = [c for c in cols_to_drop if c in df.columns]
    
    # Nhóm theo từng cửa sổ thời gian (Quá khứ -> Hiện tại -> Tương lai)
    for window_id, group in df.groupby('time_window'):
        if len(group) == 0:
            continue
            
        src_nodes = group['src_ip'].map(ip_dict).values
        dst_nodes = group['dst_ip'].map(ip_dict).values
        edge_index = torch.tensor(np.vstack([src_nodes, dst_nodes]), dtype=torch.long)
        
        edge_features = group.drop(columns=cols_to_drop).values
        edge_attr = torch.tensor(edge_features, dtype=torch.float32)
        
        labels = torch.tensor(group['label'].values, dtype=torch.long)
        
        # Bọc thành đối tượng PyG Data của KHUÔN HÌNH THỜI GIAN đó
        snapshot = Data(
            num_nodes=len(ip_dict), 
            edge_index=edge_index, 
            edge_attr=edge_attr, 
            y=labels
        )
        dynamic_graphs.append(snapshot)
        
    return dynamic_graphs

print("\n--- BƯỚC 2: CẮT ĐỒ THỊ THEO THỜI GIAN (TIME-WINDOW GRAPHS) ---")
WINDOW_SIZE = 600 # Nhóm từng khoảng 10 phút (600 giây) thành 1 đồ thị chuẩn
print(f"Đang tiến hành cắt đồ thị với cửa sổ {WINDOW_SIZE} giây / snapshot...")

train_graphs = prepare_dynamic_graphs(train_df, ip_to_id, WINDOW_SIZE)
valid_graphs = prepare_dynamic_graphs(valid_df, ip_to_id, WINDOW_SIZE)
test_graphs = prepare_dynamic_graphs(test_df, ip_to_id, WINDOW_SIZE)

print(f"-> Tập Train được cắt thành {len(train_graphs):,} Snapshots (Snapshot Đồ Thị Thời Gian)")
print(f"-> Tổng lưu lượng Edges trong Train: {sum([g.num_edges for g in train_graphs]):,}")
# Out:
# --- BƯỚC 1: XỬ LÝ IP VÀ TẠO MAPPING ---
# Tổng số Nodes (IP duy nhất) trong toàn bộ dữ liệu: 49
#
# --- BƯỚC 2: CẮT ĐỒ THỊ THEO THỜI GIAN (TIME-WINDOW GRAPHS) ---
# Đang tiến hành cắt đồ thị với cửa sổ 600 giây / snapshot...
# -> Tập Train được cắt thành 25 Snapshots (Snapshot Đồ Thị Thời Gian)
# -> Tổng lưu lượng Edges trong Train: 3,294,945

# %% [markdown]
# ### 2. Kiểm tra Đặc tính đồ thị (Graph Diagnostic Checks)
# Dùng PyTorch Geometric `Data` object để bọc dữ liệu và tiến hành check tính hợp lệ của đồ thị (Label Imbalance, NaNs/Infs, Self-loops...)

# %%
from torch_geometric.data import Data

print("--- BƯỚC 3: KIỂM TRA ĐẶC TÍNH CỦA ĐỒ THỊ THỜI GIAN (DIAGNOSTIC CHECKS) ---")

# Lấy thử Snapshot đầu tiên và Snapshot bất kỳ có nhiều luồng nhất để phân tích
max_edge_graph = max(train_graphs, key=lambda g: g.num_edges)
first_graph = train_graphs[0]

print(f"1. Cấu trúc tổng quát của MỘT SỐ Đồ thị con (Snapshot lớn nhất):")
print(f"   - Số lượng Nút (IP): {max_edge_graph.num_nodes:,} (Khung IP cố định)")
print(f"   - Số lượng Cạnh (Flows): {max_edge_graph.num_edges:,}")
print(f"   - Đồ thị có chứa vòng lặp (Self-loops): {max_edge_graph.has_self_loops()}")
print(f"   - Đồ thị có Nút cô lập (Isolated Nodes)? {max_edge_graph.has_isolated_nodes()}")

print("\n2. Kiểm tra tính hợp lệ của Feature trên Snapshot đầu tiên:")
has_nan = torch.isnan(first_graph.edge_attr).any().item()
has_inf = torch.isinf(first_graph.edge_attr).any().item()
print(f"   - Có chứa giá trị NaN? {'CÓ LỖI' if has_nan else 'Không (An toàn)'}")
print(f"   - Có chứa giá trị Inf? {'CÓ LỖI' if has_inf else 'Không (An toàn)'}")

print("\n3. Kiểm tra tính Đa đồ thị (Multi-graph) trong Snapshot 10 phút nhỏ này:")
unique_edges = torch.unique(max_edge_graph.edge_index, dim=1).shape[1]
duplicate_edges = max_edge_graph.num_edges - unique_edges
print(f"   - Số cạnh trùng lặp trên cùng cặp IP: {duplicate_edges:,} / {max_edge_graph.num_edges:,} flows")
if duplicate_edges > 0:
    print("   -> Snapshot trong 10 phút là Multi-graph, mô phỏng đúng Network Burst (Bùng nổ băng thông)!")
    print("   -> (Giải pháp E-GraphSAGE dùng aggr='max' đã được chuẩn bị để quét các tín hiệu ẩn)")

print("\n4. Kiểm tra phân phối Nhãn (Class Imbalance) trên toàn bộ các Snapshot Train:")
total_label_counts = torch.zeros(13, dtype=torch.int64) 
total_edges = sum([g.num_edges for g in train_graphs])

for g in train_graphs:
    counts = torch.bincount(g.y, minlength=13)
    total_label_counts += counts

for i, count in enumerate(total_label_counts[:13]):
    if count > 0:
        percentage = (count.item() / total_edges) * 100
        print(f"   - Lớp {i}: {count.item():>9,} flows ({percentage:>6.2f}%)")
# Out:
# --- BƯỚC 3: KIỂM TRA ĐẶC TÍNH CỦA ĐỒ THỊ THỜI GIAN (DIAGNOSTIC CHECKS) ---
# 1. Cấu trúc tổng quát của MỘT SỐ Đồ thị con (Snapshot lớn nhất):
#    - Số lượng Nút (IP): 49 (Khung IP cố định)
#    - Số lượng Cạnh (Flows): 613,217
#    - Đồ thị có chứa vòng lặp (Self-loops): False
#    - Đồ thị có Nút cô lập (Isolated Nodes)? True
#
# 2. Kiểm tra tính hợp lệ của Feature trên Snapshot đầu tiên:
#    - Có chứa giá trị NaN? Không (An toàn)
#    - Có chứa giá trị Inf? Không (An toàn)
#
# 3. Kiểm tra tính Đa đồ thị (Multi-graph) trong Snapshot 10 phút nhỏ này:
#    - Số cạnh trùng lặp trên cùng cặp IP: 613,196 / 613,217 flows
#    -> Snapshot trong 10 phút là Multi-graph, mô phỏng đúng Network Burst (Bùng nổ băng thông)!
#    -> (Giải pháp E-GraphSAGE dùng aggr='max' đã được chuẩn bị để quét các tín hiệu ẩn)
#
# 4. Kiểm tra phân phối Nhãn (Class Imbalance) trên toàn bộ các Snapshot Train:
#    - Lớp 0:   246,000 flows (  7.47%)
#    - Lớp 1:   613,217 flows ( 18.61%)
#    - Lớp 2:    92,156 flows (  2.80%)
#    - Lớp 3:   552,845 flows ( 16.78%)
#    - Lớp 4:   275,492 flows (  8.36%)
#    - Lớp 5:   234,000 flows (  7.10%)
#    - Lớp 6:   689,482 flows ( 20.93%)
#    - Lớp 7:    69,051 flows (  2.10%)
#    - Lớp 8:   157,260 flows (  4.77%)
#    - Lớp 9:     1,960 flows (  0.06%)
#    - Lớp 10:     1,358 flows (  0.04%)
#    - Lớp 11:    25,971 flows (  0.79%)
#    - Lớp 12:   336,153 flows ( 10.20%)

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import MessagePassing

# 1. ĐỊNH NGHĨA LỚP MESSAGE PASSING KẾT HỢP CẠNH (EDGE-ENHANCED SAGE)
class EdgeSAGEConv(MessagePassing):
    def __init__(self, in_channels, out_channels, edge_channels, dropout=0.2):
        # TỐI ƯU 1: Đổi từ 'mean' sang 'max' pooling
        # Vì data bị vón cục (nhiều flow cùng 1 class lấn át), 'mean' sẽ cào bằng làm tàng hình class phụ.
        # 'max' pooling giúp GraphSAGE bắt được tín hiệu của các luồng dị biệt (cực kỳ hiệu quả cho Intrusion Detection)
        super().__init__(aggr='max') 
        
        self.msg_mlp = nn.Sequential(
            nn.Linear(in_channels + edge_channels, out_channels),
            nn.LayerNorm(out_channels),
            nn.ReLU(),
            nn.Dropout(dropout) # Thêm nhiễu để bớt học vẹt bối cảnh hàng xóm
        )
        
        self.update_mlp = nn.Sequential(
            nn.Linear(in_channels + out_channels, out_channels),
            nn.LayerNorm(out_channels),
            nn.ReLU(),
            nn.Dropout(dropout)
        )

    def forward(self, x, edge_index, edge_attr):
        return self.propagate(edge_index, x=x, edge_attr=edge_attr)

    def message(self, x_j, edge_attr):
        msg_input = torch.cat([x_j, edge_attr], dim=-1)
        return self.msg_mlp(msg_input)

    def update(self, aggr_out, x):
        update_input = torch.cat([x, aggr_out], dim=-1)
        return self.update_mlp(update_input)

# 2. ĐỊNH NGHĨA MODEL TỔNG THỂ 
class EGraphSAGE(nn.Module):
    def __init__(self, num_nodes, node_emb_dim, edge_in_dim, hidden_dim, num_classes):
        super().__init__()
        self.node_emb = nn.Embedding(num_nodes, node_emb_dim)
        
        self.edge_norm = nn.LayerNorm(edge_in_dim) 
        
        # Thêm dropout nhẹ vào Convolution
        self.conv1 = EdgeSAGEConv(node_emb_dim, hidden_dim, edge_in_dim, dropout=0.1)
        self.conv2 = EdgeSAGEConv(hidden_dim, hidden_dim, edge_in_dim, dropout=0.1)
        
        classifier_dim = hidden_dim * 2 + edge_in_dim
        self.classifier = nn.Sequential(
            nn.Linear(classifier_dim, hidden_dim * 2),
            nn.LayerNorm(hidden_dim * 2),
            nn.ReLU(),
            nn.Dropout(0.4), # Tăng Dropout tầng cuối để chống Overfitting
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(hidden_dim, num_classes)
        )

    def encode_context(self, edge_index, edge_attr):
        clean_attr = torch.nan_to_num(edge_attr, nan=0.0, posinf=0.0, neginf=0.0)
        clean_attr = self.edge_norm(clean_attr)
        
        x = self.node_emb.weight
        x = F.relu(self.conv1(x, edge_index, clean_attr))
        x = self.conv2(x, edge_index, clean_attr)
        return x, clean_attr

    def predict_edges(self, x_context, clean_attr, edge_index, query_idx):
        src_nodes = edge_index[0, query_idx]
        dst_nodes = edge_index[1, query_idx]
        batch_attr = clean_attr[query_idx]
        
        edge_repr = torch.cat([x_context[src_nodes], x_context[dst_nodes], batch_attr], dim=-1)
        return self.classifier(edge_repr)

print("Đã xây dựng xong Mô Hình SAGE (Tối ưu hóa Aggregation & Dropout)!")
# Out:
# Đã xây dựng xong Mô Hình SAGE (Tối ưu hóa Aggregation & Dropout)!

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 13  # Cập nhật thành 13 lớp cho dữ liệu TCP-BASED

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 50.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.22481126 0.09018598 0.6001082  0.10003449 0.20074475 0.23634005
#  0.08021031 0.80090904 0.35166967 4.010516   4.010516   2.1294355
#  0.16451904]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device, return_probs=False):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    all_probs = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                if return_probs:
                    import torch.nn.functional as F
                    all_probs.append(F.softmax(val_out, dim=1).cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
        if return_probs:
            y_prob = np.concatenate(all_probs)
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        y_prob = []
        
    if return_probs:
        return avg_loss, macro_f1, y_true, y_pred, y_prob
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 20        
EVAL_FREQ = 2       # [TĂNG TỐC] Chỉ đánh giá (Validation) sau mỗi 2 epoch

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

# [TĂNG TỐC] Dùng AMP (Automatic Mixed Precision) để giảm một nửa thời gian train trên GPU
scaler = torch.amp.GradScaler('cuda')

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT VỚI FP16 AMP (SIÊU NHANH)
        with torch.amp.autocast('cuda'):
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            with torch.amp.autocast('cuda'):
                preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
                # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
                loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            
            # Quản lý scale loss cho FP16
            scaler.scale(loss).backward() 
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        # Step optimizer thông qua scaler
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()
            
    avg_train_loss = total_train_loss / total_train_edges
    current_lr = optimizer.param_groups[0]['lr']
    
    # [TĂNG TỐC] CHỈ CHẠY VALIDATION Ở CÁC EPOCH CHẴN
    if (epoch + 1) % EVAL_FREQ == 0 or epoch == 0:
        val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
        scheduler.step(val_f1)
        
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
        
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
        else:
            patience_counter += EVAL_FREQ
            if patience_counter >= patience:
                print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
                break
    else:
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | --- Skipped Validation ---")

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred, y_test_prob = evaluate_graphs(model, test_graphs, criterion, device, return_probs=True)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}")

auc_roc = roc_auc_score(y_test_true, y_test_prob, multi_class='ovr', average='macro')
print(f"AUC-ROC (Macro, OVR): {auc_roc:.4f}\n")

print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 5.0892 | Val Loss: 3.9286 | Val F1: 0.0142
#    -> Epoch 1: Kỷ lục F1 mới (0.0142)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 4.0666 | Val Loss: 3.3988 | Val F1: 0.0745
#    -> Epoch 2: Kỷ lục F1 mới (0.0745)! Đã lưu trọng số.
# Epoch  3/100 | LR: 0.001000 | Train Loss: 3.6372 | --- Skipped Validation ---
# Epoch  4/100 | LR: 0.001000 | Train Loss: 3.3128 | Val Loss: 2.7389 | Val F1: 0.3020
#    -> Epoch 4: Kỷ lục F1 mới (0.3020)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 2.9806 | --- Skipped Validation ---
# Epoch  6/100 | LR: 0.001000 | Train Loss: 2.9963 | Val Loss: 2.8525 | Val F1: 0.3267
#    -> Epoch 6: Kỷ lục F1 mới (0.3267)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.001000 | Train Loss: 2.9920 | --- Skipped Validation ---
# Epoch  8/100 | LR: 0.001000 | Train Loss: 2.8412 | Val Loss: 2.4297 | Val F1: 0.3766
#    -> Epoch 8: Kỷ lục F1 mới (0.3766)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.001000 | Train Loss: 2.5107 | --- Skipped Validation ---
# Epoch 10/100 | LR: 0.001000 | Train Loss: 2.5796 | Val Loss: 2.0292 | Val F1: 0.4994
#    -> Epoch 10: Kỷ lục F1 mới (0.4994)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.001000 | Train Loss: 2.7743 | --- Skipped Validation ---
# Epoch 12/100 | LR: 0.001000 | Train Loss: 2.4659 | Val Loss: 2.1415 | Val F1: 0.4199
# Epoch 13/100 | LR: 0.001000 | Train Loss: 2.3114 | --- Skipped Validation ---
# Epoch 14/100 | LR: 0.001000 | Train Loss: 2.1671 | Val Loss: 1.9001 | Val F1: 0.5751
#    -> Epoch 14: Kỷ lục F1 mới (0.5751)! Đã lưu trọng số.
# Epoch 15/100 | LR: 0.001000 | Train Loss: 2.0880 | --- Skipped Validation ---
# Epoch 16/100 | LR: 0.001000 | Train Loss: 1.9839 | Val Loss: 1.8963 | Val F1: 0.6616
#    -> Epoch 16: Kỷ lục F1 mới (0.6616)! Đã lưu trọng số.
# Epoch 17/100 | LR: 0.001000 | Train Loss: 1.9116 | --- Skipped Validation ---
# Epoch 18/100 | LR: 0.001000 | Train Loss: 1.9559 | Val Loss: 2.0838 | Val F1: 0.7002
#    -> Epoch 18: Kỷ lục F1 mới (0.7002)! Đã lưu trọng số.
# Epoch 19/100 | LR: 0.001000 | Train Loss: 1.7687 | --- Skipped Validation ---
# Epoch 20/100 | LR: 0.001000 | Train Loss: 1.8567 | Val Loss: 2.4007 | Val F1: 0.6929
# Epoch 21/100 | LR: 0.001000 | Train Loss: 1.8904 | --- Skipped Validation ---
# Epoch 22/100 | LR: 0.001000 | Train Loss: 1.8192 | Val Loss: 2.3058 | Val F1: 0.7618
#    -> Epoch 22: Kỷ lục F1 mới (0.7618)! Đã lưu trọng số.
# Epoch 23/100 | LR: 0.001000 | Train Loss: 1.7277 | --- Skipped Validation ---
# Epoch 24/100 | LR: 0.001000 | Train Loss: 1.7768 | Val Loss: 2.2028 | Val F1: 0.7688
#    -> Epoch 24: Kỷ lục F1 mới (0.7688)! Đã lưu trọng số.
# Epoch 25/100 | LR: 0.001000 | Train Loss: 1.6330 | --- Skipped Validation ---
# Epoch 26/100 | LR: 0.001000 | Train Loss: 1.6299 | Val Loss: 2.4916 | Val F1: 0.7715
#    -> Epoch 26: Kỷ lục F1 mới (0.7715)! Đã lưu trọng số.
# Epoch 27/100 | LR: 0.001000 | Train Loss: 1.6056 | --- Skipped Validation ---
# Epoch 28/100 | LR: 0.001000 | Train Loss: 1.6324 | Val Loss: 2.3878 | Val F1: 0.8239
#    -> Epoch 28: Kỷ lục F1 mới (0.8239)! Đã lưu trọng số.
# Epoch 29/100 | LR: 0.001000 | Train Loss: 1.7000 | --- Skipped Validation ---
# Epoch 30/100 | LR: 0.001000 | Train Loss: 1.6904 | Val Loss: 2.6976 | Val F1: 0.7098
# Epoch 31/100 | LR: 0.001000 | Train Loss: 1.6565 | --- Skipped Validation ---
# Epoch 32/100 | LR: 0.001000 | Train Loss: 1.6281 | Val Loss: 2.4445 | Val F1: 0.7474
# Epoch 33/100 | LR: 0.001000 | Train Loss: 1.5942 | --- Skipped Validation ---
# Epoch 34/100 | LR: 0.001000 | Train Loss: 1.6067 | Val Loss: 2.6480 | Val F1: 0.7748
# Epoch 35/100 | LR: 0.000500 | Train Loss: 1.5779 | --- Skipped Validation ---
# Epoch 36/100 | LR: 0.000500 | Train Loss: 1.5644 | Val Loss: 2.4604 | Val F1: 0.7784
# Epoch 37/100 | LR: 0.000500 | Train Loss: 1.5610 | --- Skipped Validation ---
# Epoch 38/100 | LR: 0.000500 | Train Loss: 1.5575 | Val Loss: 2.5419 | Val F1: 0.7808
# Epoch 39/100 | LR: 0.000500 | Train Loss: 1.5553 | --- Skipped Validation ---
# Epoch 40/100 | LR: 0.000500 | Train Loss: 1.5542 | Val Loss: 2.5161 | Val F1: 0.7735
# Epoch 41/100 | LR: 0.000250 | Train Loss: 1.5547 | --- Skipped Validation ---
# Epoch 42/100 | LR: 0.000250 | Train Loss: 1.5497 | Val Loss: 2.5205 | Val F1: 0.7744
# Epoch 43/100 | LR: 0.000250 | Train Loss: 1.5493 | --- Skipped Validation ---
# Epoch 44/100 | LR: 0.000250 | Train Loss: 1.5492 | Val Loss: 2.5287 | Val F1: 0.7745
# Epoch 45/100 | LR: 0.000250 | Train Loss: 1.5481 | --- Skipped Validation ---
# Epoch 46/100 | LR: 0.000250 | Train Loss: 1.5475 | Val Loss: 2.5329 | Val F1: 0.7755
# Epoch 47/100 | LR: 0.000125 | Train Loss: 1.5471 | --- Skipped Validation ---
# Epoch 48/100 | LR: 0.000125 | Train Loss: 1.5470 | Val Loss: 2.5272 | Val F1: 0.7752
#
# => EARLY STOPPING kích hoạt ở Epoch 48 (Ngừng cải thiện sau 20 epochs).
#
# Quá trình Training hoàn tất trong 1155.01 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 2.4457 | Test Macro-F1: 0.7790
# AUC-ROC (Macro, OVR): 0.9741
#
#               precision    recall  f1-score   support
#
#            0     0.2861    1.0000    0.4449    246000
#            1     0.0000    0.0000    0.0000    613218
#            2     0.9931    1.0000    0.9965     92157
#            3     1.0000    0.9924    0.9962    552847
#            4     1.0000    0.7744    0.8729    275494
#            5     1.0000    0.9969    0.9984    234000
#            6     1.0000    1.0000    1.0000    689483
#            7     0.7280    0.9986    0.8421     69052
#            8     0.8115    0.9995    0.8957    157261
#            9     0.2017    0.2982    0.2406      1962
#           10     1.0000    0.8404    0.9133      1360
#           11     0.8812    0.9753    0.9258     25973
#           12     1.0000    1.0000    1.0000    336156
#
#     accuracy                         0.7928   3294963
#    macro avg     0.7616    0.8366    0.7790   3294963
# weighted avg     0.7443    0.7928    0.7516   3294963

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 13  # Cập nhật thành 13 lớp cho dữ liệu TCP-BASED

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 50.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.22481126 0.09018598 0.6001082  0.10003449 0.20074475 0.23634005
#  0.08021031 0.80090904 0.35166967 4.010516   4.010516   2.1294355
#  0.16451904]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device, return_probs=False):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    all_probs = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                if return_probs:
                    import torch.nn.functional as F
                    all_probs.append(F.softmax(val_out, dim=1).cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
        if return_probs:
            y_prob = np.concatenate(all_probs)
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        y_prob = []
        
    if return_probs:
        return avg_loss, macro_f1, y_true, y_pred, y_prob
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 20        
EVAL_FREQ = 2       # [TĂNG TỐC] Chỉ đánh giá (Validation) sau mỗi 2 epoch

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

# [TĂNG TỐC] Dùng AMP (Automatic Mixed Precision) để giảm một nửa thời gian train trên GPU
scaler = torch.amp.GradScaler('cuda')

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT VỚI FP16 AMP (SIÊU NHANH)
        with torch.amp.autocast('cuda'):
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            with torch.amp.autocast('cuda'):
                preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
                # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
                loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            
            # Quản lý scale loss cho FP16
            scaler.scale(loss).backward() 
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        # Step optimizer thông qua scaler
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()
            
    avg_train_loss = total_train_loss / total_train_edges
    current_lr = optimizer.param_groups[0]['lr']
    
    # [TĂNG TỐC] CHỈ CHẠY VALIDATION Ở CÁC EPOCH CHẴN
    if (epoch + 1) % EVAL_FREQ == 0 or epoch == 0:
        val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
        scheduler.step(val_f1)
        
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
        
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
        else:
            patience_counter += EVAL_FREQ
            if patience_counter >= patience:
                print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
                break
    else:
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | --- Skipped Validation ---")

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred, y_test_prob = evaluate_graphs(model, test_graphs, criterion, device, return_probs=True)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}")

auc_roc = roc_auc_score(y_test_true, y_test_prob, multi_class='ovr', average='macro')
print(f"AUC-ROC (Macro, OVR): {auc_roc:.4f}\n")

print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 5.0992 | Val Loss: 4.2260 | Val F1: 0.0718
#    -> Epoch 1: Kỷ lục F1 mới (0.0718)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 4.1431 | Val Loss: 3.4243 | Val F1: 0.0942
#    -> Epoch 2: Kỷ lục F1 mới (0.0942)! Đã lưu trọng số.
# Epoch  3/100 | LR: 0.001000 | Train Loss: 3.6946 | --- Skipped Validation ---
# Epoch  4/100 | LR: 0.001000 | Train Loss: 3.3273 | Val Loss: 2.7913 | Val F1: 0.2016
#    -> Epoch 4: Kỷ lục F1 mới (0.2016)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 3.0222 | --- Skipped Validation ---
# Epoch  6/100 | LR: 0.001000 | Train Loss: 3.0569 | Val Loss: 2.7685 | Val F1: 0.2851
#    -> Epoch 6: Kỷ lục F1 mới (0.2851)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.001000 | Train Loss: 2.9590 | --- Skipped Validation ---
# Epoch  8/100 | LR: 0.001000 | Train Loss: 2.7923 | Val Loss: 2.3248 | Val F1: 0.3676
#    -> Epoch 8: Kỷ lục F1 mới (0.3676)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.001000 | Train Loss: 2.7134 | --- Skipped Validation ---
# Epoch 10/100 | LR: 0.001000 | Train Loss: 2.4906 | Val Loss: 2.1969 | Val F1: 0.4494
#    -> Epoch 10: Kỷ lục F1 mới (0.4494)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.001000 | Train Loss: 2.3952 | --- Skipped Validation ---
# Epoch 12/100 | LR: 0.001000 | Train Loss: 2.4322 | Val Loss: 2.1665 | Val F1: 0.5337
#    -> Epoch 12: Kỷ lục F1 mới (0.5337)! Đã lưu trọng số.
# Epoch 13/100 | LR: 0.001000 | Train Loss: 2.4380 | --- Skipped Validation ---
# Epoch 14/100 | LR: 0.001000 | Train Loss: 2.2202 | Val Loss: 2.7489 | Val F1: 0.4140
# Epoch 15/100 | LR: 0.001000 | Train Loss: 2.4453 | --- Skipped Validation ---
# Epoch 16/100 | LR: 0.001000 | Train Loss: 2.2938 | Val Loss: 2.0847 | Val F1: 0.5944
#    -> Epoch 16: Kỷ lục F1 mới (0.5944)! Đã lưu trọng số.
# Epoch 17/100 | LR: 0.001000 | Train Loss: 2.0765 | --- Skipped Validation ---
# Epoch 18/100 | LR: 0.001000 | Train Loss: 2.1730 | Val Loss: 2.1193 | Val F1: 0.5783
# Epoch 19/100 | LR: 0.001000 | Train Loss: 2.0409 | --- Skipped Validation ---
# Epoch 20/100 | LR: 0.001000 | Train Loss: 2.0166 | Val Loss: 1.9145 | Val F1: 0.6764
#    -> Epoch 20: Kỷ lục F1 mới (0.6764)! Đã lưu trọng số.
# Epoch 21/100 | LR: 0.001000 | Train Loss: 1.7779 | --- Skipped Validation ---
# Epoch 22/100 | LR: 0.001000 | Train Loss: 1.7744 | Val Loss: 2.0912 | Val F1: 0.7137
#    -> Epoch 22: Kỷ lục F1 mới (0.7137)! Đã lưu trọng số.
# Epoch 23/100 | LR: 0.001000 | Train Loss: 1.6867 | --- Skipped Validation ---
# Epoch 24/100 | LR: 0.001000 | Train Loss: 1.6465 | Val Loss: 1.8842 | Val F1: 0.7520
#    -> Epoch 24: Kỷ lục F1 mới (0.7520)! Đã lưu trọng số.
# Epoch 25/100 | LR: 0.001000 | Train Loss: 1.6501 | --- Skipped Validation ---
# Epoch 26/100 | LR: 0.001000 | Train Loss: 1.7251 | Val Loss: 2.4131 | Val F1: 0.7683
#    -> Epoch 26: Kỷ lục F1 mới (0.7683)! Đã lưu trọng số.
# Epoch 27/100 | LR: 0.001000 | Train Loss: 1.6462 | --- Skipped Validation ---
# Epoch 28/100 | LR: 0.001000 | Train Loss: 1.6705 | Val Loss: 2.2661 | Val F1: 0.7410
# Epoch 29/100 | LR: 0.001000 | Train Loss: 1.5990 | --- Skipped Validation ---
# Epoch 30/100 | LR: 0.001000 | Train Loss: 1.5893 | Val Loss: 2.3221 | Val F1: 0.7507
# Epoch 31/100 | LR: 0.001000 | Train Loss: 1.5956 | --- Skipped Validation ---
# Epoch 32/100 | LR: 0.001000 | Train Loss: 1.5798 | Val Loss: 2.4633 | Val F1: 0.7811
#    -> Epoch 32: Kỷ lục F1 mới (0.7811)! Đã lưu trọng số.
# Epoch 33/100 | LR: 0.001000 | Train Loss: 1.5975 | --- Skipped Validation ---
# Epoch 34/100 | LR: 0.001000 | Train Loss: 1.5896 | Val Loss: 2.2025 | Val F1: 0.7230
# Epoch 35/100 | LR: 0.001000 | Train Loss: 1.5956 | --- Skipped Validation ---
# Epoch 36/100 | LR: 0.001000 | Train Loss: 1.6163 | Val Loss: 2.6542 | Val F1: 0.6618
# Epoch 37/100 | LR: 0.001000 | Train Loss: 1.6265 | --- Skipped Validation ---
# Epoch 38/100 | LR: 0.001000 | Train Loss: 1.5662 | Val Loss: 2.4089 | Val F1: 0.8312
#    -> Epoch 38: Kỷ lục F1 mới (0.8312)! Đã lưu trọng số.
# Epoch 39/100 | LR: 0.001000 | Train Loss: 1.5716 | --- Skipped Validation ---
# Epoch 40/100 | LR: 0.001000 | Train Loss: 1.5802 | Val Loss: 2.5600 | Val F1: 0.7691
# Epoch 41/100 | LR: 0.001000 | Train Loss: 1.5602 | --- Skipped Validation ---
# Epoch 42/100 | LR: 0.001000 | Train Loss: 1.5810 | Val Loss: 2.4056 | Val F1: 0.7799
# Epoch 43/100 | LR: 0.001000 | Train Loss: 1.5682 | --- Skipped Validation ---
# Epoch 44/100 | LR: 0.001000 | Train Loss: 1.5596 | Val Loss: 2.4037 | Val F1: 0.8262
# Epoch 45/100 | LR: 0.000500 | Train Loss: 1.5526 | --- Skipped Validation ---
# Epoch 46/100 | LR: 0.000500 | Train Loss: 1.5461 | Val Loss: 2.4878 | Val F1: 0.8166
# Epoch 47/100 | LR: 0.000500 | Train Loss: 1.5431 | --- Skipped Validation ---
# Epoch 48/100 | LR: 0.000500 | Train Loss: 1.5428 | Val Loss: 2.5018 | Val F1: 0.7939
# Epoch 49/100 | LR: 0.000500 | Train Loss: 1.5414 | --- Skipped Validation ---
# Epoch 50/100 | LR: 0.000500 | Train Loss: 1.5428 | Val Loss: 2.5183 | Val F1: 0.7949
# Epoch 51/100 | LR: 0.000250 | Train Loss: 1.5425 | --- Skipped Validation ---
# Epoch 52/100 | LR: 0.000250 | Train Loss: 1.5402 | Val Loss: 2.4914 | Val F1: 0.7938
# Epoch 53/100 | LR: 0.000250 | Train Loss: 1.5400 | --- Skipped Validation ---
# Epoch 54/100 | LR: 0.000250 | Train Loss: 1.5394 | Val Loss: 2.5034 | Val F1: 0.8039
# Epoch 55/100 | LR: 0.000250 | Train Loss: 1.5392 | --- Skipped Validation ---
# Epoch 56/100 | LR: 0.000250 | Train Loss: 1.5390 | Val Loss: 2.5028 | Val F1: 0.8064
# Epoch 57/100 | LR: 0.000125 | Train Loss: 1.5388 | --- Skipped Validation ---
# Epoch 58/100 | LR: 0.000125 | Train Loss: 1.5390 | Val Loss: 2.4972 | Val F1: 0.8077
#
# => EARLY STOPPING kích hoạt ở Epoch 58 (Ngừng cải thiện sau 20 epochs).
#
# Quá trình Training hoàn tất trong 1413.02 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 2.4465 | Test Macro-F1: 0.7372
# AUC-ROC (Macro, OVR): 0.9925
#
#               precision    recall  f1-score   support
#
#            0     0.2880    0.9985    0.4471    246000
#            1     0.0000    0.0000    0.0000    613218
#            2     1.0000    0.9857    0.9928     92157
#            3     1.0000    0.9977    0.9989    552847
#            4     1.0000    0.7754    0.8735    275494
#            5     1.0000    0.9970    0.9985    234000
#            6     1.0000    1.0000    1.0000    689483
#            7     0.5066    0.8976    0.6477     69052
#            8     0.9474    0.9995    0.9728    157261
#            9     0.0832    0.3053    0.1308      1962
#           10     0.4349    1.0000    0.6062      1360
#           11     0.8766    0.9588    0.9159     25973
#           12     0.9996    1.0000    0.9998    336156
#
#     accuracy                         0.7911   3294963
#    macro avg     0.7028    0.8397    0.7372   3294963
# weighted avg     0.7461    0.7911    0.7515   3294963

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch
import torch.nn as nn

print("--- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Đang sử dụng thiết bị: {device}")

node_emb_dim = 128
hidden_dim = 256  
edge_in_dim = train_graphs[0].edge_attr.shape[1]

num_classes = 13  # Cập nhật thành 13 lớp cho dữ liệu TCP-BASED

model = EGraphSAGE(
    num_nodes=len(ip_to_id),
    node_emb_dim=node_emb_dim,
    edge_in_dim=edge_in_dim,
    hidden_dim=hidden_dim,
    num_classes=num_classes
).to(device)

optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='max', factor=0.5, patience=2)

print("\n[Tự động] Tính toán Class Weights...")
total_label_counts = torch.zeros(num_classes, dtype=torch.int64)
for g in train_graphs:
    counts = torch.bincount(g.y, minlength=num_classes)
    total_label_counts += counts

# Ngăn lỗi chia cho 0
total_label_counts = torch.where(total_label_counts == 0, torch.ones_like(total_label_counts), total_label_counts)

# Tính nghịch đảo tuyến tính gốc
weights = 1.0 / total_label_counts.float()

# TỐI ƯU 3: WEIGHT CLAMPING MỀM HƠN
# Để Dynamic Undersampling phát huy tác dụng, ta nới rộng tỉ lệ trần là 500 (thay vì 100)
min_weight = weights.min()
max_weight = min_weight * 50.0  
weights = torch.clamp(weights, min=min_weight, max=max_weight)

# Chuẩn hoá weights
weights = weights / weights.sum() * num_classes 
weights = weights.to(device)

print(" -> Trọng số (Class Weights - Clamped) đã tính xong:", weights.cpu().numpy())

# TỐI ƯU 4: LABEL SMOOTHING = 0.05
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.05)

print("\nKhởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.")
# Out:
# --- BƯỚC 4: KHỞI TẠO MÔ HÌNH VÀ THUẬT TOÁN TỐI ƯU ---
# Đang sử dụng thiết bị: cuda
#
# [Tự động] Tính toán Class Weights...
#  -> Trọng số (Class Weights - Clamped) đã tính xong: [0.22481126 0.09018598 0.6001082  0.10003449 0.20074475 0.23634005
#  0.08021031 0.80090904 0.35166967 4.010516   4.010516   2.1294355
#  0.16451904]
#
# Khởi tạo hoàn tất! Cấu hình nâng cấp với CLAMPED WEIGHTS + LABEL SMOOTHING đã sẵn sàng huấn luyện.

# %%
import copy
import time
import random
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score

print("--- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---")

def evaluate_graphs(model, graphs, criterion, device, return_probs=False):
    """Hàm đánh giá Cấu trúc mới"""
    model.eval()
    total_loss = 0
    total_edges = sum(g.num_edges for g in graphs)
    all_preds = []
    all_trues = []
    all_probs = []
    
    with torch.no_grad():
        for g in graphs:
            if g.num_edges == 0:
                continue
                
            g_edge_idx = g.edge_index.to(device)
            g_edge_attr = g.edge_attr.to(device)
            g_y = g.y.to(device)
            
            # GỘP 1: Dọn rác và Xây Context
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
            
            # GỘP 2: Chia mẻ nhỏ Predict Tránh bể RAM
            for i in range(0, g.num_edges, 100000): 
                idx = torch.arange(i, min(i+100000, g.num_edges), device=device)
                
                val_out = model.predict_edges(x_ctx, clean_attr, g_edge_idx, idx)
                loss = criterion(val_out, g_y[idx])
                
                total_loss += loss.item() * len(idx)
                all_preds.append(torch.argmax(val_out, dim=1).cpu().numpy())
                all_trues.append(g_y[idx].cpu().numpy())
                if return_probs:
                    import torch.nn.functional as F
                    all_probs.append(F.softmax(val_out, dim=1).cpu().numpy())
                
    avg_loss = total_loss / (total_edges if total_edges > 0 else 1)
    
    if len(all_preds) > 0:
        y_pred = np.concatenate(all_preds)
        y_true = np.concatenate(all_trues)
        macro_f1 = classification_report(y_true, y_pred, output_dict=True, zero_division=0)['macro avg']['f1-score']
        if return_probs:
            y_prob = np.concatenate(all_probs)
    else:
        macro_f1, y_pred, y_true = 0.0, [], []
        y_prob = []
        
    if return_probs:
        return avg_loss, macro_f1, y_true, y_pred, y_prob
    return avg_loss, macro_f1, y_true, y_pred

# THIẾT LẬP THAM SỐ
epochs = 100
batch_size = 65536  # Tăng chunk lên để lướt siêu nhanh
patience = 20        
EVAL_FREQ = 2       # [TĂNG TỐC] Chỉ đánh giá (Validation) sau mỗi 2 epoch

best_val_f1 = -1.0
best_model_wts = copy.deepcopy(model.state_dict())
patience_counter = 0
total_train_edges = sum(g.num_edges for g in train_graphs)

# [TĂNG TỐC] Dùng AMP (Automatic Mixed Precision) để giảm một nửa thời gian train trên GPU
scaler = torch.amp.GradScaler('cuda')

print(f"\n=> Bắt đầu huấn luyện {epochs} Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...")
start_time = time.time()

for epoch in range(epochs):
    model.train()
    total_train_loss = 0
    
    random.shuffle(train_graphs)
    
    for graph_idx, g in enumerate(train_graphs):
        if g.num_edges == 0:
            continue
            
        g_edge_idx = g.edge_index.to(device)
        g_edge_attr = g.edge_attr.to(device)
        g_y = g.y.to(device)
        
        optimizer.zero_grad()
        
        # 1. CHỈ TÍNH BỐI CẢNH 1 LẦN DUY NHẤT VỚI FP16 AMP (SIÊU NHANH)
        with torch.amp.autocast('cuda'):
            x_ctx, clean_attr = model.encode_context(g_edge_idx, g_edge_attr)
        
        # 2. TÁCH RỜI ĐỒ THỊ ĐỂ CHẶN BACKWARD LAN SÂU XUỐNG DƯỚI
        x_ctx_det = x_ctx.detach().requires_grad_(True)
        clean_attr_det = clean_attr.detach().requires_grad_(True)
        
        perm = torch.randperm(g.num_edges, device=device)
        
        # 3. CHỈ BACKWARD CỤC BỘ DÀNH CHO PHẦN CLASSIFIER
        for i in range(0, g.num_edges, batch_size):
            idx = perm[i:i+batch_size]
            
            with torch.amp.autocast('cuda'):
                preds = model.predict_edges(x_ctx_det, clean_attr_det, g_edge_idx, idx)
                # Loss được chia tỉ lệ theo batch để mô phỏng chính xác Full-Batch Gradient
                loss = criterion(preds, g_y[idx]) * (len(idx) / g.num_edges)
            
            # Quản lý scale loss cho FP16
            scaler.scale(loss).backward() 
            total_train_loss += loss.item() * g.num_edges
            
        # Kiểm tra tính toàn vẹn Gradient
        gx = x_ctx_det.grad if x_ctx_det.grad is not None else torch.zeros_like(x_ctx_det)
        gc = clean_attr_det.grad if clean_attr_det.grad is not None else torch.zeros_like(clean_attr_det)
        
        # 4. GỘP TOÀN BỘ YÊU CẦU GRADIENT VÀ TRUYỀN NGƯỢC QUA GNN
        torch.autograd.backward(
            tensors=[x_ctx, clean_attr],
            grad_tensors=[gx, gc]
        )
        
        # Step optimizer thông qua scaler
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        scaler.step(optimizer)
        scaler.update()
            
    avg_train_loss = total_train_loss / total_train_edges
    current_lr = optimizer.param_groups[0]['lr']
    
    # [TĂNG TỐC] CHỈ CHẠY VALIDATION Ở CÁC EPOCH CHẴN
    if (epoch + 1) % EVAL_FREQ == 0 or epoch == 0:
        val_loss, val_f1, _, _ = evaluate_graphs(model, valid_graphs, criterion, device)
        scheduler.step(val_f1)
        
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | Val Loss: {val_loss:.4f} | Val F1: {val_f1:.4f}")
        
        if val_f1 > best_val_f1:
            best_val_f1 = val_f1
            best_model_wts = copy.deepcopy(model.state_dict())
            patience_counter = 0
            print(f"   -> Epoch {epoch+1}: Kỷ lục F1 mới ({val_f1:.4f})! Đã lưu trọng số.")
        else:
            patience_counter += EVAL_FREQ
            if patience_counter >= patience:
                print(f"\n=> EARLY STOPPING kích hoạt ở Epoch {epoch+1} (Ngừng cải thiện sau {patience} epochs).")
                break
    else:
        print(f"Epoch {epoch+1:>2}/{epochs} | LR: {current_lr:.6f} | Train Loss: {avg_train_loss:.4f} | --- Skipped Validation ---")

print(f"\nQuá trình Training hoàn tất trong {time.time() - start_time:.2f} giây.")

print("\n--- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---")
model.load_state_dict(best_model_wts)
test_loss, test_f1, y_test_true, y_test_pred, y_test_prob = evaluate_graphs(model, test_graphs, criterion, device, return_probs=True)

print(f"Test Loss: {test_loss:.4f} | Test Macro-F1: {test_f1:.4f}")

auc_roc = roc_auc_score(y_test_true, y_test_prob, multi_class='ovr', average='macro')
print(f"AUC-ROC (Macro, OVR): {auc_roc:.4f}\n")

print(classification_report(y_test_true, y_test_pred, digits=4, zero_division=0))
# Out:
# --- BƯỚC 5: HUẤN LUYỆN, EARLY STOPPING & ĐÁNH GIÁ (ANTI-NAN GRAPHS) ---
#
# => Bắt đầu huấn luyện 100 Epochs với KỸ THUẬT SIÊU TỐC (Manual Gradient Accumulation + AMP)...
# Epoch  1/100 | LR: 0.001000 | Train Loss: 4.7038 | Val Loss: 4.8665 | Val F1: 0.0142
#    -> Epoch 1: Kỷ lục F1 mới (0.0142)! Đã lưu trọng số.
# Epoch  2/100 | LR: 0.001000 | Train Loss: 4.4433 | Val Loss: 3.4874 | Val F1: 0.0873
#    -> Epoch 2: Kỷ lục F1 mới (0.0873)! Đã lưu trọng số.
# Epoch  3/100 | LR: 0.001000 | Train Loss: 3.8665 | --- Skipped Validation ---
# Epoch  4/100 | LR: 0.001000 | Train Loss: 3.4761 | Val Loss: 3.1125 | Val F1: 0.1267
#    -> Epoch 4: Kỷ lục F1 mới (0.1267)! Đã lưu trọng số.
# Epoch  5/100 | LR: 0.001000 | Train Loss: 3.1358 | --- Skipped Validation ---
# Epoch  6/100 | LR: 0.001000 | Train Loss: 3.1053 | Val Loss: 2.7407 | Val F1: 0.2530
#    -> Epoch 6: Kỷ lục F1 mới (0.2530)! Đã lưu trọng số.
# Epoch  7/100 | LR: 0.001000 | Train Loss: 2.9700 | --- Skipped Validation ---
# Epoch  8/100 | LR: 0.001000 | Train Loss: 2.6626 | Val Loss: 2.5303 | Val F1: 0.3032
#    -> Epoch 8: Kỷ lục F1 mới (0.3032)! Đã lưu trọng số.
# Epoch  9/100 | LR: 0.001000 | Train Loss: 2.6284 | --- Skipped Validation ---
# Epoch 10/100 | LR: 0.001000 | Train Loss: 2.5365 | Val Loss: 2.5289 | Val F1: 0.3838
#    -> Epoch 10: Kỷ lục F1 mới (0.3838)! Đã lưu trọng số.
# Epoch 11/100 | LR: 0.001000 | Train Loss: 2.5806 | --- Skipped Validation ---
# Epoch 12/100 | LR: 0.001000 | Train Loss: 2.6338 | Val Loss: 2.0739 | Val F1: 0.5735
#    -> Epoch 12: Kỷ lục F1 mới (0.5735)! Đã lưu trọng số.
# Epoch 13/100 | LR: 0.001000 | Train Loss: 2.5093 | --- Skipped Validation ---
# Epoch 14/100 | LR: 0.001000 | Train Loss: 2.2726 | Val Loss: 1.9764 | Val F1: 0.5463
# Epoch 15/100 | LR: 0.001000 | Train Loss: 2.1232 | --- Skipped Validation ---
# Epoch 16/100 | LR: 0.001000 | Train Loss: 2.1951 | Val Loss: 1.9411 | Val F1: 0.5263
# Epoch 17/100 | LR: 0.001000 | Train Loss: 2.2405 | --- Skipped Validation ---
# Epoch 18/100 | LR: 0.001000 | Train Loss: 2.5427 | Val Loss: 2.2456 | Val F1: 0.5409
# Epoch 19/100 | LR: 0.000500 | Train Loss: 1.9133 | --- Skipped Validation ---
# Epoch 20/100 | LR: 0.000500 | Train Loss: 1.8121 | Val Loss: 2.0261 | Val F1: 0.7203
#    -> Epoch 20: Kỷ lục F1 mới (0.7203)! Đã lưu trọng số.
# Epoch 21/100 | LR: 0.000500 | Train Loss: 1.7151 | --- Skipped Validation ---
# Epoch 22/100 | LR: 0.000500 | Train Loss: 1.7177 | Val Loss: 2.2469 | Val F1: 0.7277
#    -> Epoch 22: Kỷ lục F1 mới (0.7277)! Đã lưu trọng số.
# Epoch 23/100 | LR: 0.000500 | Train Loss: 1.6437 | --- Skipped Validation ---
# Epoch 24/100 | LR: 0.000500 | Train Loss: 1.6451 | Val Loss: 2.2946 | Val F1: 0.7536
#    -> Epoch 24: Kỷ lục F1 mới (0.7536)! Đã lưu trọng số.
# Epoch 25/100 | LR: 0.000500 | Train Loss: 1.6070 | --- Skipped Validation ---
# Epoch 26/100 | LR: 0.000500 | Train Loss: 1.5922 | Val Loss: 2.4197 | Val F1: 0.7605
#    -> Epoch 26: Kỷ lục F1 mới (0.7605)! Đã lưu trọng số.
# Epoch 27/100 | LR: 0.000500 | Train Loss: 1.6221 | --- Skipped Validation ---
# Epoch 28/100 | LR: 0.000500 | Train Loss: 1.5848 | Val Loss: 2.4141 | Val F1: 0.7653
#    -> Epoch 28: Kỷ lục F1 mới (0.7653)! Đã lưu trọng số.
# Epoch 29/100 | LR: 0.000500 | Train Loss: 1.5836 | --- Skipped Validation ---
# Epoch 30/100 | LR: 0.000500 | Train Loss: 1.5768 | Val Loss: 2.4459 | Val F1: 0.7683
#    -> Epoch 30: Kỷ lục F1 mới (0.7683)! Đã lưu trọng số.
# Epoch 31/100 | LR: 0.000500 | Train Loss: 1.5834 | --- Skipped Validation ---
# Epoch 32/100 | LR: 0.000500 | Train Loss: 1.5721 | Val Loss: 2.5390 | Val F1: 0.7724
#    -> Epoch 32: Kỷ lục F1 mới (0.7724)! Đã lưu trọng số.
# Epoch 33/100 | LR: 0.000500 | Train Loss: 1.5680 | --- Skipped Validation ---
# Epoch 34/100 | LR: 0.000500 | Train Loss: 1.5666 | Val Loss: 2.6212 | Val F1: 0.7676
# Epoch 35/100 | LR: 0.000500 | Train Loss: 1.5643 | --- Skipped Validation ---
# Epoch 36/100 | LR: 0.000500 | Train Loss: 1.5658 | Val Loss: 2.5795 | Val F1: 0.7790
#    -> Epoch 36: Kỷ lục F1 mới (0.7790)! Đã lưu trọng số.
# Epoch 37/100 | LR: 0.000500 | Train Loss: 1.5684 | --- Skipped Validation ---
# Epoch 38/100 | LR: 0.000500 | Train Loss: 1.5613 | Val Loss: 2.3337 | Val F1: 0.7813
#    -> Epoch 38: Kỷ lục F1 mới (0.7813)! Đã lưu trọng số.
# Epoch 39/100 | LR: 0.000500 | Train Loss: 1.5871 | --- Skipped Validation ---
# Epoch 40/100 | LR: 0.000500 | Train Loss: 1.5661 | Val Loss: 2.5063 | Val F1: 0.7812
# Epoch 41/100 | LR: 0.000500 | Train Loss: 1.5607 | --- Skipped Validation ---
# Epoch 42/100 | LR: 0.000500 | Train Loss: 1.5644 | Val Loss: 2.6665 | Val F1: 0.7703
# Epoch 43/100 | LR: 0.000500 | Train Loss: 1.5655 | --- Skipped Validation ---
# Epoch 44/100 | LR: 0.000500 | Train Loss: 1.5547 | Val Loss: 2.6270 | Val F1: 0.7854
#    -> Epoch 44: Kỷ lục F1 mới (0.7854)! Đã lưu trọng số.
# Epoch 45/100 | LR: 0.000500 | Train Loss: 1.5583 | --- Skipped Validation ---
# Epoch 46/100 | LR: 0.000500 | Train Loss: 1.5566 | Val Loss: 2.6452 | Val F1: 0.7916
#    -> Epoch 46: Kỷ lục F1 mới (0.7916)! Đã lưu trọng số.
# Epoch 47/100 | LR: 0.000500 | Train Loss: 1.5547 | --- Skipped Validation ---
# Epoch 48/100 | LR: 0.000500 | Train Loss: 1.5502 | Val Loss: 2.6429 | Val F1: 0.7956
#    -> Epoch 48: Kỷ lục F1 mới (0.7956)! Đã lưu trọng số.
# Epoch 49/100 | LR: 0.000500 | Train Loss: 1.5493 | --- Skipped Validation ---
# Epoch 50/100 | LR: 0.000500 | Train Loss: 1.5478 | Val Loss: 2.7277 | Val F1: 0.7872
# Epoch 51/100 | LR: 0.000500 | Train Loss: 1.5502 | --- Skipped Validation ---
# Epoch 52/100 | LR: 0.000500 | Train Loss: 1.5469 | Val Loss: 2.6835 | Val F1: 0.7906
# Epoch 53/100 | LR: 0.000500 | Train Loss: 1.5488 | --- Skipped Validation ---
# Epoch 54/100 | LR: 0.000500 | Train Loss: 1.5432 | Val Loss: 2.6661 | Val F1: 0.7874
# Epoch 55/100 | LR: 0.000250 | Train Loss: 1.5427 | --- Skipped Validation ---
# Epoch 56/100 | LR: 0.000250 | Train Loss: 1.5410 | Val Loss: 2.7025 | Val F1: 0.7885
# Epoch 57/100 | LR: 0.000250 | Train Loss: 1.5408 | --- Skipped Validation ---
# Epoch 58/100 | LR: 0.000250 | Train Loss: 1.5403 | Val Loss: 2.6859 | Val F1: 0.7880
# Epoch 59/100 | LR: 0.000250 | Train Loss: 1.5400 | --- Skipped Validation ---
# Epoch 60/100 | LR: 0.000250 | Train Loss: 1.5397 | Val Loss: 2.6865 | Val F1: 0.7887
# Epoch 61/100 | LR: 0.000125 | Train Loss: 1.5395 | --- Skipped Validation ---
# Epoch 62/100 | LR: 0.000125 | Train Loss: 1.5394 | Val Loss: 2.6872 | Val F1: 0.7889
# Epoch 63/100 | LR: 0.000125 | Train Loss: 1.5394 | --- Skipped Validation ---
# Epoch 64/100 | LR: 0.000125 | Train Loss: 1.5391 | Val Loss: 2.6873 | Val F1: 0.7884
# Epoch 65/100 | LR: 0.000125 | Train Loss: 1.5391 | --- Skipped Validation ---
# Epoch 66/100 | LR: 0.000125 | Train Loss: 1.5389 | Val Loss: 2.6901 | Val F1: 0.7883
# Epoch 67/100 | LR: 0.000063 | Train Loss: 1.5387 | --- Skipped Validation ---
# Epoch 68/100 | LR: 0.000063 | Train Loss: 1.5386 | Val Loss: 2.6911 | Val F1: 0.7883
#
# => EARLY STOPPING kích hoạt ở Epoch 68 (Ngừng cải thiện sau 20 epochs).
#
# Quá trình Training hoàn tất trong 1607.96 giây.
#
# --- BƯỚC 6: ĐÁNH GIÁ TRÊN TẬP TEST TEST (VỚI MODEL TỐT NHẤT) ---
# Test Loss: 2.6204 | Test Macro-F1: 0.7474
# AUC-ROC (Macro, OVR): 0.9668
#
#               precision    recall  f1-score   support
#
#            0     0.2863    1.0000    0.4451    246000
#            1     0.0000    0.0000    0.0000    613218
#            2     0.9735    1.0000    0.9866     92157
#            3     1.0000    0.9969    0.9984    552847
#            4     1.0000    0.6894    0.8162    275494
#            5     1.0000    0.9969    0.9985    234000
#            6     1.0000    1.0000    1.0000    689483
#            7     0.7240    0.9629    0.8265     69052
#            8     0.7198    0.9995    0.8369    157261
#            9     0.3399    0.6453    0.4452      1962
#           10     0.2855    1.0000    0.4442      1360
#           11     0.9971    0.8528    0.9193     25973
#           12     0.9996    1.0000    0.9998    336156
#
#     accuracy                         0.7850   3294963
#    macro avg     0.7174    0.8572    0.7474   3294963
# weighted avg     0.7400    0.7850    0.7437   3294963
